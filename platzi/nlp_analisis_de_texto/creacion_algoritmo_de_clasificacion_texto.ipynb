# %% [markdown]
# # Entrenando un Modelo Markoviano Latente (HMM)

# %% [markdown]
# ## Corpus de español:
#
# * AnCora | Github: https://github.com/UniversalDependencies/UD_Spanish-AnCora
#
# * usamos el conllu parser para leer el corpus: https://pypi.org/project/conllu/
#
# * Etiquetas Universal POS (Documentación): https://universaldependencies.org/u/pos/

# %%
#@title dependencias previas
# !pip install conllu
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Collecting conllu
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.5.3
# Cloning into 'UD_Spanish-AnCora'...
# remote: Enumerating objects: 1347, done.
# remote: Counting objects: 100% (363/363), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 1347 (delta 282), reused 357 (delta 276), pack-reused 984
# Receiving objects: 100% (1347/1347), 432.33 MiB | 19.03 MiB/s, done.
# Resolving deltas: 100% (975/975), done.

# %%
from conllu import parse_incr
from collections import defaultdict
import numpy as np
import nltk
from nltk import word_tokenize

# %%
with open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8") as data_file:
    for tokenlist in parse_incr(data_file):
        print(tokenlist.serialize())
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 3	EJ10	EJ10	PROPN	_	_	2	flat	2:flat	_
# 4-5	del	_	_	_	_	_	_	_	_
# 4	de	de	ADP	spcms	_	6	case	6:case	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	_
# 6	alemán	alemán	NOUN	ncms000	Gender=Masc|Number=Sing	2	nmod	2:nmod	Entity=(CESSCASTAA2000062923978c27-person-1-gstype:spec
# 7	Heinz-Harald	Heinz-Harald	PROPN	np00000	_	6	appos	6:appos	MWE=Heinz-Harald_Frentzen|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 8	Frentzen	Frentzen	PROPN	_	_	7	flat	7:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)
# 9	,	,	PUNCT	fc	PunctType=Comm	10	punct	10:punct	Entity=(CESSCASTAA2000062923978c27-person-2-CorefType:pred.definit,gstype:spec
# 10	vencedor	vencedor	NOUN	ncms000	Gender=Masc|Number=Sing	6	appos	6:appos	_
# 11	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	13:det	_
# 12	pasado	pasado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	13	amod	13:amod	_
# 13	año	año	NOUN	ncms000	Gender=Masc|Number=Sing	10	appos	10:appos	_
# 14	bajo	bajo	ADP	sps00	_	16	case	16:case	_
# 15	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	16	det	16:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 16	diluvio	diluvio	NOUN	ncms000	Gender=Masc|Number=Sing	10	nmod	10:nmod	Entity=NOCOREF:Gen)CESSCASTAA2000062923978c27)CESSCASTAA2000062923978c27)
# 17	y	y	CCONJ	cc	_	20	cc	20:cc	_
# 18-19	del	_	_	_	_	_	_	_	_
# 18	de	de	ADP	spcms	_	20	case	20:case	_
# 19	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	20	det	20:det	_
# 20	italiano	italiano	NOUN	ncms000	Gender=Masc|Number=Sing	6	conj	6:conj	Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 21	Jarno	Jarno	PROPN	np00000	_	20	appos	20:appos	MWE=Jarno_Trulli|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 22	Trulli	Trulli	PROPN	_	_	21	flat	21:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)NOCOREF:Spec.person)
# 23	,	,	PUNCT	fc	PunctType=Comm	27	punct	27:punct	Entity=CESSCASTAA2000062923978c39)
# 24	así	así	ADV	cc	_	27	cc	27:cc	MWE=así_como|MWEPOS=CCONJ
# 25	como	como	SCONJ	_	_	24	fixed	24:fixed	_
# 26	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	27	det	27:det	Entity=(CESSCASTAA2000062923978c40--2-gstype:gen,HomoDD
# 27	Williams-BMW	Williams-BMW	PROPN	np00000	_	2	conj	2:conj	_
# 28-29	del	_	_	_	_	_	_	_	_
# 28	de	de	ADP	spcms	_	30	case	30:case	_
# 29	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	30	det	30:det	_
# 30	alemán	alemán	NOUN	ncms000	Gender=Masc|Number=Sing	27	nmod	27:nmod	Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 31	Ralf	Ralf	PROPN	np00000	_	30	appos	30:appos	MWE=Ralf_Schumacher|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 32	Schumacher	Schumacher	PROPN	_	_	31	flat	31:flat	Entity=NOCOREF:Spec.person)NOCOREF:Spec.person)
# 33	y	y	CCONJ	cc	_	36	cc	36:cc	_
# 34-35	del	_	_	_	_	_	_	_	_
# 34	de	de	ADP	spcms	_	36	case	36:case	_
# 35	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	36	det	36:det	_
# 36	británico	británico	NOUN	ncms000	Gender=Masc|Number=Sing	30	conj	30:conj	Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 37	Jenson	Jenson	PROPN	np00000	_	36	appos	36:appos	MWE=Jenson_Button|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 38	Button	Button	PROPN	_	_	37	flat	37:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)NOCOREF:Spec.person)
# 39	,	,	PUNCT	fc	PunctType=Comm	49	punct	49:punct	_
# 40	a	a	ADP	cs	_	49	mark	49:mark	MWE=a_pesar_de_que|MWEPOS=SCONJ
# 41	pesar	pesar	NOUN	_	_	40	fixed	40:fixed	_
# 42	de	de	ADP	_	_	40	fixed	40:fixed	_
# 43	que	que	SCONJ	_	_	40	fixed	40:fixed	_
# 43.1	_	_	PRON	p	_	_	_	46:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTAA2000062923978c40--1-CorefType:ident,gstype:gen)
# 44	no	no	ADV	rn	Polarity=Neg	49	advmod	49:advmod	_
# 45	han	haber	AUX	vaip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	49	aux	49:aux	_
# 46	estado	estar	AUX	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	49	cop	49:cop	_
# 47	a	a	ADP	sps00	_	49	case	49:case	_
# 48	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	49	det	49:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 49	altura	altura	NOUN	ncfs000	Gender=Fem|Number=Sing	27	acl	27:acl	ArgTem=arg2:atr
# 50	de	de	ADP	sps00	_	52	case	52:case	_
# 51	lo	él	PRON	da0ns0	Case=Acc|Definite=Def|Gender=Masc|Number=Sing|Person=3|PrepCase=Npr|PronType=Prs	52	det	52:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 52	esperado	esperado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	49	amod	49:amod	Entity=NOCOREF:Gen)NOCOREF:Gen)
# 53	en	en	ADP	sps00	_	57	case	57:case	_
# 54	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	57	det	57:det	Entity=(NOCOREF:Gen--4-gstype:gen,HomoDD
# 55	tres	tres	NUM	dn0cp0	Number=Plur|NumForm=Word|NumType=Card	54	nummod	54:nummod	_
# 56	últimas	último	ADJ	ao0fp0	Gender=Fem|Number=Plur|NumType=Ord	57	amod	57:amod	_
# 57	carreras	carrera	NOUN	ncfp000	Gender=Fem|Number=Plur	49	obl	49:obl	ArgTem=argM:loc|Entity=NOCOREF:Gen)CESSCASTAA2000062923978c40)NOCOREF:Gen)
# 58	y	y	CCONJ	cc	_	60	cc	60:cc	_
# 59	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	60	det	60:det	Entity=(NOCOREF:Gen--9-gstype:gen,HomoDD(CESSCASTAA2000062923978c41--2-gstype:gen,HomoDD
# 60	BAR-Honda	BAR-Honda	PROPN	np00000	_	2	conj	2:conj	_
# 61-62	del	_	_	_	_	_	_	_	_
# 61	de	de	ADP	spcms	_	63	case	63:case	_
# 62	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	63	det	63:det	_
# 63	canadiense	canadiense	NOUN	nccs000	Number=Sing	60	nmod	60:nmod	Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 64	Jacques	Jacques	PROPN	np00000	_	63	appos	63:appos	MWE=Jacques_Villeneuve|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 65	Villeneuve	Villeneuve	PROPN	_	_	64	flat	64:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)NOCOREF:Spec.person)
# 66	,	,	PUNCT	fc	PunctType=Comm	70	punct	70:punct	Entity=CESSCASTAA2000062923978c41)
# 67	junto	junto	ADJ	sps00	_	70	cc	70:cc	MWE=junto_con|MWEPOS=ADP
# 68	con	con	ADP	_	_	67	fixed	67:fixed	_
# 69	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	70	det	70:det	Entity=(CESSCASTAA2000062923978c38-organization-2-CorefType:ident,gstype:spec
# 70	Arrows	Arrows	PROPN	np00000	_	2	conj	2:conj	_
# 71	de	de	ADP	sps00	_	74	case	74:case	_
# 72	De	De	ADP	np00000	_	74	case	74:case	MWE=De_la_Rosa|MWEPOS=PROPN|Entity=(CESSCASTAA2000062923978c14-person-3-CorefType:ident,gstype:spec
# 73	la	el	DET	_	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	74	det	74:det	_
# 74	Rosa	Rosa	PROPN	_	_	70	nmod	70:nmod	Entity=CESSCASTAA2000062923978c14)
# 75	y	y	CCONJ	cc	_	76	cc	76:cc	_
# 76	Verstappen	Verstappen	PROPN	np00000	_	74	conj	74:conj	SpaceAfter=No|Entity=(CESSCASTAA2000062923978c29-person-1-CorefType:ident,gstype:spec)CESSCASTAA2000062923978c38)NOCOREF:Gen)
# 77	,	,	PUNCT	fc	PunctType=Comm	2	punct	2:punct	_
# 78	son	ser	AUX	vsip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	82	cop	82:cop	_
# 79	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	82	det	82:det	Entity=(CESSCASTAA2000062923978c38_PLUS_CESSCASTAA2000062923978c39_PLUS_CESSCASTAA2000062923978c40_PLUS_CESSCASTAA2000062923978c41--4-CorefType:pred.definit|SplitAnte=CESSCASTAA2000062923978c38<CESSCASTAA2000062923978c38_PLUS_CESSCASTAA2000062923978c39_PLUS_CESSCASTAA2000062923978c40_PLUS_CESSCASTAA2000062923978c41,CESSCASTAA2000062923978c39<CESSCASTAA2000062923978c38_PLUS_CESSCASTAA2000062923978c39_PLUS_CESSCASTAA2000062923978c40_PLUS_CESSCASTAA2000062923978c41,CESSCASTAA2000062923978c40<CESSCASTAA2000062923978c38_PLUS_CESSCASTAA2000062923978c39_PLUS_CESSCASTAA2000062923978c40_PLUS_CESSCASTAA2000062923978c41,CESSCASTAA2000062923978c41<CESSCASTAA2000062923978c38_PLUS_CESSCASTAA2000062923978c39_PLUS_CESSCASTAA2000062923978c40_PLUS_CESSCASTAA2000062923978c41
# 80	más	más	ADV	rg	Degree=Cmp	81	advmod	81:advmod	ArgTem=argM:adv
# 81	cualificados	cualificado	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	82	amod	82:amod	_
# 82	aspirantes	aspirante	NOUN	nccp000	Number=Plur	0	root	0:root	ArgTem=arg2:atr
# 83	a	a	ADP	sps00	_	84	mark	84:mark	_
# 84	entrar	entrar	VERB	vmn0000	VerbForm=Inf	82	acl	82:acl	_
# 85	en	en	ADP	sps00	_	87	case	87:case	_
# 86	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	87	det	87:det	Entity=(CESSCASTAA2000062923978c25--2-CorefType:ident,gstype:gen,HomoDD
# 87	puntos	punto	NOUN	ncmp000	Gender=Masc|Number=Plur	84	obl	84:obl	SpaceAfter=No|ArgTem=arg2:loc|Entity=CESSCASTAA2000062923978c25)CESSCASTAA2000062923978c38_PLUS_CESSCASTAA2000062923978c39_PLUS_CESSCASTAA2000062923978c40_PLUS_CESSCASTAA2000062923978c41)
# 88	.	.	PUNCT	fp	PunctType=Peri	82	punct	82:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000629-23978-s12
# # text = La escudería Prost-Peugeot es la única junto con Minardi en no haber sumado puntos para el mundial.
# 1	La	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA2000062923978c31-organization-2-gstype:spec
# 2	escudería	escudería	NOUN	ncfs000	Gender=Fem|Number=Sing	6	nsubj	6:nsubj	ArgTem=arg1:tem
# 3	Prost-Peugeot	Prost-Peugeot	PROPN	np00000	_	2	appos	2:appos	Entity=(NOCOREF:Spec.organization-organization-1-gstype:spec)CESSCASTAA2000062923978c31)
# 4	es	ser	AUX	vsip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	6	cop	6:cop	_
# 5	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	6	det	6:det	Entity=(CESSCASTAA2000062923978c31-organization-2-CorefType:pred.definit,gstype:spec
# 6	única	único	ADJ	aq0fs0	Gender=Fem|Number=Sing	0	root	0:root	ArgTem=arg2:atr|Entity=CESSCASTAA2000062923978c31)
# 7	junto	junto	ADJ	sps00	_	9	case	9:case	MWE=junto_con|MWEPOS=ADP
# 8	con	con	ADP	_	_	7	fixed	7:fixed	_
# 9	Minardi	Minardi	PROPN	np00000	_	6	obl	6:obl	ArgTem=argM:adv|Entity=(CESSCASTAA2000062923978c20-organization-1-CorefType:ident,gstype:spec)
# 10	en	en	ADP	sps00	_	13	mark	13:mark	_
# 11	no	no	ADV	rn	Polarity=Neg	13	advmod	13:advmod	_
# 12	haber	haber	AUX	van0000	VerbForm=Inf	13	aux	13:aux	_
# 13	sumado	sumar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	6	advcl	6:advcl	_
# 14	puntos	punto	NOUN	ncmp000	Gender=Masc|Number=Plur	13	obj	13:obj	ArgTem=arg1:pat|Entity=(NOCOREF:Gen--1-gstype:gen
# 15	para	para	ADP	sps00	_	17	case	17:case	_
# 16	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	17:det	Entity=(CESSCASTAA2000062923978c32--2-CorefType:ident,gstype:gen,HomoDD
# 17	mundial	mundial	NOUN	ncms000	Gender=Masc|Number=Sing	14	nmod	14:nmod	SpaceAfter=No|Entity=CESSCASTAA2000062923978c32)NOCOREF:Gen)
# 18	.	.	PUNCT	fp	PunctType=Peri	6	punct	6:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000629-23978-s13
# # text = Prost corre delante de su público y Peugeot pondrá a disposición de los pilotos, el francés Jean Alesi y el alemán Nick Heidfeld, la cuarta evolución del motor E20 para la sesión de clasificación del Sábado, para intentar que el equipo del cuádruple campeón del mundo pueda salir del pozo en que se encuentra.
# 1	Prost	Prost	PROPN	np00000	_	2	nsubj	2:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA2000062923978c42-person-1-CorefType:ident,gstype:spec)
# 2	corre	correr	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 3	delante	delante	ADV	rg	_	2	advmod	2:advmod	ArgTem=arg2:loc
# 4	de	de	ADP	sps00	_	6	case	6:case	_
# 5	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	6	det	6:det	Entity=(NOCOREF:Gen--2-gstype:gen(CESSCASTAA2000062923978c42-person-1-CorefType:ident,gstype:spec)
# 6	público	público	NOUN	ncms000	Gender=Masc|Number=Sing	3	obl	3:obl	Entity=NOCOREF:Gen)
# 7	y	y	CCONJ	cc	_	9	cc	9:cc	_
# 8	Peugeot	Peugeot	PROPN	np00000	_	9	nsubj	9:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA2000062923978c36-organization-1-gstype:spec)
# 9	pondrá	poner	VERB	vmif3s0	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	2	conj	2:conj	_
# 10	a	a	ADP	sps00	_	11	case	11:case	_
# 11	disposición	disposición	NOUN	ncfs000	Gender=Fem|Number=Sing	9	obl	9:obl	ArgTem=argL:|Entity=(NOCOREF:Gen--1-gstype:gen
# 12	de	de	ADP	sps00	_	14	case	14:case	_
# 13	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	14	det	14:det	Entity=(CESSCASTAA2000062923978c33--2-gstype:gen,HomoDD
# 14	pilotos	piloto	NOUN	nccp000	Number=Plur	11	nmod	11:nmod	SpaceAfter=No|ArgTem=arg0:agt
# 15	,	,	PUNCT	fc	PunctType=Comm	17	punct	17:punct	Entity=(CESSCASTAA2000062923978c33--3-CorefType:pred.definit,gstype:gen
# 16	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	17:det	Entity=(NOCOREF:Spec.person-person-2-gstype:spec
# 17	francés	francés	NOUN	ncms000	Gender=Masc|Number=Sing	14	appos	14:appos	_
# 18	Jean	Jean	PROPN	np00000	_	17	appos	17:appos	MWE=Jean_Alesi|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 19	Alesi	Alesi	PROPN	_	_	18	flat	18:flat	Entity=NOCOREF:Spec.person)NOCOREF:Spec.person)
# 20	y	y	CCONJ	cc	_	22	cc	22:cc	_
# 21	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	22	det	22:det	Entity=(NOCOREF:Spec.person-person-2-gstype:spec
# 22	alemán	alemán	NOUN	ncms000	Gender=Masc|Number=Sing	17	conj	17:conj	_
# 23	Nick	Nick	PROPN	np00000	_	22	appos	22:appos	MWE=Nick_Heidfeld|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 24	Heidfeld	Heidfeld	PROPN	_	_	23	flat	23:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)NOCOREF:Spec.person)
# 25	,	,	PUNCT	fc	PunctType=Comm	17	punct	17:punct	Entity=CESSCASTAA2000062923978c33)CESSCASTAA2000062923978c33)NOCOREF:Gen)
# 26	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	28	det	28:det	Entity=(NOCOREF:Gen--3-gstype:gen,HomoDD
# 27	cuarta	cuarto	ADJ	ao0fs0	Gender=Fem|Number=Sing|NumType=Ord	28	amod	28:amod	_
# 28	evolución	evolución	NOUN	ncfs000	Gender=Fem|Number=Sing	9	obj	9:obj	ArgTem=arg1:pat
# 29-30	del	_	_	_	_	_	_	_	_
# 29	de	de	ADP	spcms	_	31	case	31:case	_
# 30	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	_
# 31	motor	motor	NOUN	ncms000	Gender=Masc|Number=Sing	28	nmod	28:nmod	ArgTem=arg1:tem|Entity=(NOCOREF:Spec.other-other-1-gstype:spec
# 32	E20	E20	PROPN	np00000	_	31	appos	31:appos	Entity=(NOCOREF:Spec.other-other-1-gstype:spec)NOCOREF:Spec.other)NOCOREF:Gen)
# 33	para	para	ADP	sps00	_	35	case	35:case	_
# 34	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	35	det	35:det	Entity=(CESSCASTAA2000062923978c34--2-CorefType:ident,gstype:gen,HomoDD
# 35	sesión	sesión	NOUN	ncfs000	Gender=Fem|Number=Sing	9	obl	9:obl	ArgTem=argM:adv
# 36	de	de	ADP	sps00	_	37	case	37:case	_
# 37	clasificación	clasificación	NOUN	ncfs000	Gender=Fem|Number=Sing	35	nmod	35:nmod	_
# 38-39	del	_	_	_	_	_	_	_	_
# 38	de	de	ADP	spcms	_	40	case	40:case	_
# 39	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	40	det	40:det	_
# 40	Sábado	Sábado	NOUN	_	AdvType=Tim	35	nmod	35:nmod	SpaceAfter=No|Entity=(CESSCASTAA2000062923978c37-time-1-gstype:spec)CESSCASTAA2000062923978c34)
# 41	,	,	PUNCT	fc	PunctType=Comm	43	punct	43:punct	_
# 42	para	para	ADP	sps00	_	43	mark	43:mark	_
# 43	intentar	intentar	VERB	vmn0000	VerbForm=Inf	9	advcl	9:advcl	ArgTem=argM:fin
# 44	que	que	SCONJ	cs	_	43	mark	43:mark	_
# 45	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	46	det	46:det	Entity=(CESSCASTAA2000062923978c36-organization-2-CorefType:ident,gstype:spec
# 46	equipo	equipo	NOUN	ncms000	Gender=Masc|Number=Sing	43	nsubj	43:nsubj	ArgTem=arg1:tem
# 47-48	del	_	_	_	_	_	_	_	_
# 47	de	de	ADP	spcms	_	50	case	50:case	_
# 48	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	50	det	50:det	_
# 49	cuádruple	cuádruple	NUM	dn0cs0	Number=Sing|NumForm=Word|NumType=Card	50	nummod	50:nummod	Entity=(CESSCASTAA2000062923978c42-person-2-CorefType:ident,gstype:spec
# 50	campeón	campeón	NOUN	ncms000	Gender=Masc|Number=Sing	46	nmod	46:nmod	_
# 51-52	del	_	_	_	_	_	_	_	_
# 51	de	de	ADP	spcms	_	53	case	53:case	_
# 52	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	53	det	53:det	_
# 53	mundo	mundo	NOUN	ncms000	Gender=Masc|Number=Sing	50	nmod	50:nmod	Entity=CESSCASTAA2000062923978c42)CESSCASTAA2000062923978c36)
# 54	pueda	poder	AUX	vmsp3s0	Mood=Sub|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	43	aux	43:aux	_
# 55	salir	salir	VERB	vmn0000	VerbForm=Inf	43	xcomp	43:xcomp	ArgTem=arg1:pat
# 56-57	del	_	_	_	_	_	_	_	_
# 56	de	de	ADP	spcms	_	58	case	58:case	_
# 57	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	58	det	58:det	_
# 58	pozo	pozo	NOUN	ncms000	Gender=Masc|Number=Sing	43	obl	43:obl	ArgTem=arg2:loc|Entity=(CESSCASTAA2000062923978c35--1-gstype:gen,HomoDD
# 59	en	en	ADP	sps00	_	60	case	60:case	_
# 60	que	que	PRON	pr0cn000	PronType=Rel	62	obl	62:obl	ArgTem=arg2:loc|Entity=(CESSCASTAA2000062923978c35--1-CorefType:ident,gstype:gen)
# 60.1	_	_	PRON	p	_	_	_	62:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTAA2000062923978c36-organization-1-CorefType:ident,gstype:spec)
# 61	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	62	expl:pv	62:expl:pv	_
# 62	encuentra	encontrar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	58	acl	58:acl	SpaceAfter=No|Entity=CESSCASTAA2000062923978c35)
# 63	.	.	PUNCT	fp	PunctType=Peri	2	punct	2:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000629-23978-s14
# # text = Mañana, viernes, la jornada estará dedicada a los entrenamientos libres, mientras que el Sábado, tras una nueva sesión libre se disputará la clasificación para establecer la formación de salida de la carrera del domingo.
# 1	Mañana	mañana	ADV	rg	_	8	advmod	8:advmod	SpaceAfter=No|ArgTem=argM:tmp
# 2	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	Entity=(NOCOREF:Spec.date-time-2-gstype:spec
# 3	viernes	viernes	NOUN	_	AdvType=Tim	1	obl	1:obl	SpaceAfter=No
# 4	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	Entity=NOCOREF:Spec.date)
# 5	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	6	det	6:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 6	jornada	jornada	NOUN	ncfs000	Gender=Fem|Number=Sing	8	nsubj	8:nsubj	ArgTem=arg1:tem|Entity=NOCOREF:Gen)
# 7	estará	estar	AUX	vmif3s0	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	8	cop	8:cop	_
# 8	dedicada	dedicado	ADJ	aq0fsp	Gender=Fem|Number=Sing|VerbForm=Part	14	parataxis	14:parataxis	ArgTem=arg2:atr
# 9	a	a	ADP	sps00	_	11	case	11:case	_
# 10	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	11	det	11:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 11	entrenamientos	entrenamiento	NOUN	ncmp000	Gender=Masc|Number=Plur	8	obj	8:obj	ArgTem=arg2:tem
# 12	libres	libre	ADJ	aq0cp0	Number=Plur	11	amod	11:amod	SpaceAfter=No|Entity=NOCOREF:Gen)
# 13	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	_
# 14	mientras	mientras	CCONJ	cc	_	0	root	0:root	MWE=mientras_que|MWEPOS=CCONJ
# 15	que	que	SCONJ	_	_	14	fixed	14:fixed	_
# 16	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	17:det	Entity=(CESSCASTAA2000062923978c37-time-2-CorefType:ident,gstype:spec
# 17	Sábado	Sábado	NOUN	_	AdvType=Tim	25	obl	25:obl	SpaceAfter=No|ArgTem=argM:tmp
# 18	,	,	PUNCT	fc	PunctType=Comm	17	punct	17:punct	Entity=CESSCASTAA2000062923978c37)
# 19	tras	tras	ADP	sps00	_	22	case	22:case	_
# 20	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	22	det	22:det	Entity=(NOCOREF:Gen--3-gstype:gen
# 21	nueva	nuevo	ADJ	aq0fs0	Gender=Fem|Number=Sing	22	amod	22:amod	_
# 22	sesión	sesión	NOUN	ncfs000	Gender=Fem|Number=Sing	25	obl	25:obl	ArgTem=argM:tmp
# 23	libre	libre	ADJ	aq0cs0	Number=Sing	22	amod	22:amod	Entity=NOCOREF:Gen)
# 24	se	él	PRON	p0000000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	25	expl:pass	25:expl:pass	_
# 25	disputará	disputar	VERB	vmif3s0	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	14	parataxis	14:parataxis	_
# 26	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	27	det	27:det	Entity=(CESSCASTAA2000062923978c34--2-CorefType:ident,gstype:gen,HomoDD
# 27	clasificación	clasificación	NOUN	ncfs000	Gender=Fem|Number=Sing	25	nsubj	25:nsubj	ArgTem=arg1:pat
# 28	para	para	ADP	sps00	_	29	mark	29:mark	_
# 29	establecer	establecer	VERB	vmn0000	VerbForm=Inf	27	acl	27:acl	ArgTem=argM:fin
# 30	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	31	det	31:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 31	formación	formación	NOUN	ncfs000	Gender=Fem|Number=Sing	29	obj	29:obj	ArgTem=arg1:pat
# 32	de	de	ADP	sps00	_	33	case	33:case	_
# 33	salida	salida	NOUN	ncfs000	Gender=Fem|Number=Sing	31	nmod	31:nmod	_
# 34	de	de	ADP	sps00	_	36	case	36:case	_
# 35	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	36	det	36:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 36	carrera	carrera	NOUN	ncfs000	Gender=Fem|Number=Sing	33	nmod	33:nmod	_
# 37-38	del	_	_	_	_	_	_	_	_
# 37	de	de	ADP	spcms	_	39	case	39:case	_
# 38	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	39	det	39:det	_
# 39	domingo	domingo	NOUN	_	AdvType=Tim	36	nmod	36:nmod	SpaceAfter=No|Entity=(NOCOREF:Spec.date-time-1-gstype:spec)NOCOREF:Gen)NOCOREF:Gen)CESSCASTAA2000062923978c34)
# 40	.	.	PUNCT	fp	PunctType=Peri	14	punct	14:punct	_
#
#
# # global.Entity = eid-etype-head-other
# # newdoc id = CESS-CAST-AA-20000704-2484
# # sent_id = CESS-CAST-AA-20000704-2484-s1
# # text = Al menos 23 empresas exportadoras de café de Honduras han quebrado en los últimos tres años, muchas de ellas por el impacto del bajo precio del grano en el mercado internacional, informó hoy, Martes, una fuente empresarial.
# 1-2	Al	_	_	_	_	_	_	_	MWE=Al_menos|MWEPOS=ADV
# 1	A	a	ADP	rg	_	5	case	5:case	MWE=Al_menos|MWEPOS=ADV
# 2	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	5	det	5:det	_
# 3	menos	menos	ADV	_	Degree=Cmp	1	fixed	1:fixed	_
# 4	23	23	NUM	_	NumForm=Digit|NumType=Card	5	nummod	5:nummod	Entity=(CESSCASTAA200007042484c2--2-gstype:gen
# 5	empresas	empresa	NOUN	ncfp000	Gender=Fem|Number=Plur	12	nsubj	12:nsubj	ArgTem=arg1:tem
# 6	exportadoras	exportadora	NOUN	ncfp000	Gender=Fem|Number=Plur	5	nmod	5:nmod	_
# 7	de	de	ADP	sps00	_	8	case	8:case	_
# 8	café	café	NOUN	ncms000	Gender=Masc|Number=Sing	6	nmod	6:nmod	Entity=(CESSCASTAA200007042484c1--1-gstype:gen)
# 9	de	de	ADP	sps00	_	10	case	10:case	_
# 10	Honduras	Honduras	PROPN	np00000	_	5	nmod	5:nmod	Entity=(CESSCASTAA200007042484c15-place-1-gstype:spec)CESSCASTAA200007042484c2)
# 11	han	haber	AUX	vaip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	12	aux	12:aux	_
# 12	quebrado	quebrar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	37	ccomp	37:ccomp	ArgTem=arg1:pat
# 13	en	en	ADP	sps00	_	17	case	17:case	_
# 14	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	17	det	17:det	Entity=(NOCOREF:Gen--4-gstype:gen,HomoDD
# 15	últimos	último	ADJ	ao0mp0	Gender=Masc|Number=Plur|NumType=Ord	14	amod	14:amod	_
# 16	tres	tres	NUM	dn0cp0	Number=Plur|NumForm=Word|NumType=Card	14	nummod	14:nummod	_
# 17	años	año	NOUN	ncmp000	Gender=Masc|Number=Plur	12	obl	12:obl	SpaceAfter=No|ArgTem=argM:tmp|Entity=NOCOREF:Gen)
# 18	,	,	PUNCT	fc	PunctType=Comm	19	punct	19:punct	_
# 19	muchas	mucho	PRON	pi0fp000	Gender=Fem|Number=Plur|NumType=Card|PronType=Ind	12	obl	12:obl	Entity=(NOCOREF:Gen--1-gstype:gen
# 20	de	de	ADP	sps00	_	21	case	21:case	_
# 21	ellas	él	PRON	pp3fp000	Case=Acc,Nom|Gender=Fem|Number=Plur|Person=3|PronType=Prs	19	nmod	19:nmod	Entity=(CESSCASTAA200007042484c2--1-CorefType:ident,gstype:gen)NOCOREF:Gen)
# 22	por	por	ADP	sps00	_	24	case	24:case	_
# 23	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	24	det	24:det	Entity=(CESSCASTAA200007042484c11--2-gstype:gen,HomoDD
# 24	impacto	impacto	NOUN	ncms000	Gender=Masc|Number=Sing	19	nmod	19:nmod	_
# 25-26	del	_	_	_	_	_	_	_	_
# 25	de	de	ADP	spcms	_	28	case	28:case	_
# 26	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	28	det	28:det	_
# 27	bajo	bajo	ADJ	aq0ms0	Gender=Masc|Number=Sing	28	amod	28:amod	Entity=(CESSCASTAA200007042484c6--2-gstype:gen,HomoDD
# 28	precio	precio	NOUN	ncms000	Gender=Masc|Number=Sing	24	nmod	24:nmod	_
# 29-30	del	_	_	_	_	_	_	_	_
# 29	de	de	ADP	spcms	_	31	case	31:case	_
# 30	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	_
# 31	grano	grano	NOUN	ncms000	Gender=Masc|Number=Sing	28	nmod	28:nmod	Entity=(CESSCASTAA200007042484c1--1-CorefType:ident,gstype:gen)CESSCASTAA200007042484c6)
# 32	en	en	ADP	sps00	_	34	case	34:case	_
# 33	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	34	det	34:det	Entity=(CESSCASTAA200007042484c13--2-gstype:gen,HomoDD
# 34	mercado	mercado	NOUN	ncms000	Gender=Masc|Number=Sing	24	nmod	24:nmod	_
# 35	internacional	internacional	ADJ	aq0cs0	Number=Sing	34	amod	34:amod	SpaceAfter=No|Entity=CESSCASTAA200007042484c13)CESSCASTAA200007042484c11)
# 36	,	,	PUNCT	fc	PunctType=Comm	12	punct	12:punct	_
# 37	informó	informar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 38	hoy	hoy	ADV	rg	_	37	advmod	37:advmod	SpaceAfter=No|ArgTem=argM:tmp
# 39	,	,	PUNCT	fc	PunctType=Comm	40	punct	40:punct	Entity=(NOCOREF:Spec.date-time-2-gstype:spec
# 40	Martes	Martes	NOUN	_	AdvType=Tim	38	obl	38:obl	SpaceAfter=No
# 41	,	,	PUNCT	fc	PunctType=Comm	40	punct	40:punct	Entity=NOCOREF:Spec.date)
# 42	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	43	det	43:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 43	fuente	fuente	NOUN	ncfs000	Gender=Fem|Number=Sing	37	nsubj	37:nsubj	ArgTem=arg0:agt
# 44	empresarial	empresarial	ADJ	aq0cs0	Number=Sing	43	amod	43:amod	SpaceAfter=No|Entity=NOCOREF:Gen)
# 45	.	.	PUNCT	fp	PunctType=Peri	37	punct	37:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s2
# # text = El cierre de esas empresas también afectó a varios bancos privados que les habían concedido créditos y que en algunos casos no pudieron recuperar ni mediante la subasta de bienes.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 2	cierre	cierre	NOUN	ncms000	Gender=Masc|Number=Sing	7	nsubj	7:nsubj	ArgTem=arg0:cau
# 3	de	de	ADP	sps00	_	5	case	5:case	_
# 4	esas	ese	DET	dd0fp0	Gender=Fem|Number=Plur|PronType=Dem	5	det	5:det	Entity=(CESSCASTAA200007042484c2--2-CorefType:ident,gstype:gen
# 5	empresas	empresa	NOUN	ncfp000	Gender=Fem|Number=Plur	2	nmod	2:nmod	ArgTem=arg1:pat|Entity=CESSCASTAA200007042484c2)NOCOREF:Gen)
# 6	también	también	ADV	rg	_	7	advmod	7:advmod	_
# 7	afectó	afectar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 8	a	a	ADP	sps00	_	10	case	10:case	_
# 9	varios	varios	DET	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	10	det	10:det	Entity=(CESSCASTAA200007042484c3--2-gstype:gen
# 10	bancos	banco	NOUN	ncmp000	Gender=Masc|Number=Plur	7	obj	7:obj	ArgTem=arg1:tem
# 11	privados	privado	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	10	amod	10:amod	_
# 12	que	que	PRON	pr0cn000	PronType=Rel	15	nsubj	15:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c3--1-CorefType:ident,gstype:gen)
# 13	les	él	PRON	pp3cpd00	Case=Dat|Number=Plur|Person=3|PronType=Prs	15	obl:arg	15:obl:arg	ArgTem=arg2:ben|Entity=(CESSCASTAA200007042484c2--1-CorefType:ident,gstype:gen)
# 14	habían	haber	AUX	vaii3p0	Mood=Ind|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin	15	aux	15:aux	_
# 15	concedido	conceder	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	10	acl	10:acl	_
# 16	créditos	crédito	NOUN	ncmp000	Gender=Masc|Number=Plur	15	obj	15:obj	ArgTem=arg1:pat|Entity=(NOCOREF:Gen--1-gstype:gen)
# 17	y	y	CCONJ	cc	_	24	cc	24:cc	_
# 18	que	que	PRON	pr0cn000	PronType=Rel	24	nsubj	24:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c3--1-CorefType:ident,gstype:gen)
# 19	en	en	ADP	sps00	_	21	case	21:case	_
# 20	algunos	alguno	DET	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	21	det	21:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 21	casos	caso	NOUN	ncmp000	Gender=Masc|Number=Plur	24	obl	24:obl	ArgTem=argM:adv|Entity=NOCOREF:Gen)
# 22	no	no	ADV	rn	Polarity=Neg	24	advmod	24:advmod	_
# 23	pudieron	poder	AUX	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	24	aux	24:aux	_
# 24	recuperar	recuperar	VERB	vmn0000	VerbForm=Inf	15	conj	15:conj	_
# 25	ni	ni	ADV	rg	_	24	advmod	24:advmod	_
# 26	mediante	mediante	ADP	sps00	_	25	case	25:case	_
# 27	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	28	det	28:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 28	subasta	subasta	NOUN	ncfs000	Gender=Fem|Number=Sing	25	nmod	25:nmod	ArgTem=argM:adv
# 29	de	de	ADP	sps00	_	30	case	30:case	_
# 30	bienes	bien	NOUN	ncmp000	Gender=Masc|Number=Plur	28	nmod	28:nmod	SpaceAfter=No|ArgTem=arg1:pat|Entity=(NOCOREF:Gen--1-gstype:gen)NOCOREF:Gen)CESSCASTAA200007042484c3)
# 31	.	.	PUNCT	fp	PunctType=Peri	7	punct	7:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s3
# # text = El presidente de la Asociación de Exportadores de Café de Honduras (ADECAFEH), Javier Echeverría, dijo que hasta 1997 había 60 empresas exportadoras, pero ahora sólo quedan 37.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200007042484c4-person-2-gstype:spec
# 2	presidente	presidente	NOUN	ncms000	Gender=Masc|Number=Sing	19	nsubj	19:nsubj	ArgTem=arg0:agt
# 3	de	de	ADP	sps00	_	5	case	5:case	_
# 4	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	5:det	Entity=(CESSCASTAA200007042484c5-organization-2-gstype:spec
# 5	Asociación	Asociación	PROPN	np00000	_	2	nmod	2:nmod	MWE=Asociación_de_Exportadores_de_Café_de_Honduras|MWEPOS=PROPN
# 6	de	de	ADP	_	_	7	case	7:case	_
# 7	Exportadores	Exportadores	PROPN	_	_	5	flat	5:flat	_
# 8	de	de	ADP	_	_	9	case	9:case	_
# 9	Café	Café	PROPN	_	_	5	flat	5:flat	_
# 10	de	de	ADP	_	_	11	case	11:case	_
# 11	Honduras	Honduras	PROPN	_	_	5	flat	5:flat	_
# 12	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	13	punct	13:punct	SpaceAfter=No|Entity=(CESSCASTAA200007042484c5-organization-2-CorefType:pred.definit,gstype:spec
# 13	ADECAFEH	ADECAFEH	PROPN	np00000	_	5	flat	5:flat	SpaceAfter=No
# 14	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	13	punct	13:punct	SpaceAfter=No|Entity=CESSCASTAA200007042484c5)CESSCASTAA200007042484c5)
# 15	,	,	PUNCT	fc	PunctType=Comm	16	punct	16:punct	Entity=(CESSCASTAA200007042484c4-person-2-CorefType:pred.definit,gstype:spec
# 16	Javier	Javier	PROPN	np00000	_	2	appos	2:appos	MWE=Javier_Echeverría|MWEPOS=PROPN
# 17	Echeverría	Echeverría	PROPN	_	_	16	flat	16:flat	SpaceAfter=No
# 18	,	,	PUNCT	fc	PunctType=Comm	16	punct	16:punct	Entity=CESSCASTAA200007042484c4)CESSCASTAA200007042484c4)
# 19	dijo	decir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 20	que	que	SCONJ	cs	_	23	mark	23:mark	_
# 21	hasta	hasta	ADP	sps00	_	22	case	22:case	_
# 22	1997	1997	NOUN	_	AdvType=Tim	23	obl	23:obl	ArgTem=argM:tmp|Entity=(NOCOREF:Spec.date-time-1-gstype:spec)
# 23	había	haber	VERB	vaii3s0	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	19	ccomp	19:ccomp	ArgTem=arg1:pat
# 24	60	60	NUM	_	NumForm=Digit|NumType=Card	25	nummod	25:nummod	Entity=(NOCOREF:Gen--2-gstype:gen
# 25	empresas	empresa	NOUN	ncfp000	Gender=Fem|Number=Plur	23	obj	23:obj	ArgTem=arg1:tem
# 26	exportadoras	exportador	ADJ	aq0fp0	Gender=Fem|Number=Plur	25	amod	25:amod	SpaceAfter=No|Entity=NOCOREF:Gen)
# 27	,	,	PUNCT	fc	PunctType=Comm	31	punct	31:punct	_
# 28	pero	pero	CCONJ	cc	_	31	cc	31:cc	_
# 29	ahora	ahora	ADV	rg	_	31	advmod	31:advmod	ArgTem=argM:tmp
# 30	sólo	sólo	ADV	rg	_	31	advmod	31:advmod	_
# 31	quedan	quedar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	23	conj	23:conj	_
# 32	37	37	NUM	_	NumForm=Digit|NumType=Card	31	nsubj	31:nsubj	SpaceAfter=No|ArgTem=arg1:tem|Entity=(NOCOREF:Spec.number-number-1-gstype:spec)
# 33	.	.	PUNCT	fp	PunctType=Peri	19	punct	19:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s4
# # text = Las empresas sufrieron graves problemas financieros por la caída del precio internacional del café, pues quedaron con mucho grano almacenado, que tuvieron que vender a un valor muy inferior al de compra, explicó Echeverría.
# 1	Las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200007042484c7--2-gstype:gen,HomoDD
# 2	empresas	empresa	NOUN	ncfp000	Gender=Fem|Number=Plur	3	nsubj	3:nsubj	ArgTem=arg1:tem|Entity=CESSCASTAA200007042484c7)
# 3	sufrieron	sufrir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	39	ccomp	39:ccomp	ArgTem=arg1:pat
# 4	graves	grave	ADJ	aq0cp0	Number=Plur	5	amod	5:amod	Entity=(NOCOREF:Gen--2-gstype:gen
# 5	problemas	problema	NOUN	ncmp000	Gender=Masc|Number=Plur	3	obj	3:obj	ArgTem=arg2:atr
# 6	financieros	financiero	ADJ	aq0mp0	Gender=Masc|Number=Plur	5	amod	5:amod	Entity=NOCOREF:Gen)
# 7	por	por	ADP	sps00	_	9	case	9:case	_
# 8	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	9	det	9:det	Entity=(CESSCASTAA200007042484c6--2-CorefType:ident,gstype:gen,HomoDD
# 9	caída	caída	NOUN	ncfs000	Gender=Fem|Number=Sing	3	obl	3:obl	ArgTem=argM:cau
# 10-11	del	_	_	_	_	_	_	_	_
# 10	de	de	ADP	spcms	_	12	case	12:case	_
# 11	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	12	det	12:det	_
# 12	precio	precio	NOUN	ncms000	Gender=Masc|Number=Sing	9	nmod	9:nmod	ArgTem=arg1:tem|Entity=(CESSCASTAA200007042484c17--1-gstype:gen,HomoDD
# 13	internacional	internacional	ADJ	aq0cs0	Number=Sing	12	amod	12:amod	_
# 14-15	del	_	_	_	_	_	_	_	_
# 14	de	de	ADP	spcms	_	16	case	16:case	_
# 15	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	16	det	16:det	_
# 16	café	café	NOUN	ncms000	Gender=Masc|Number=Sing	12	nmod	12:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007042484c1--1-CorefType:ident,gstype:gen,HomoDD)CESSCASTAA200007042484c17)CESSCASTAA200007042484c6)
# 17	,	,	PUNCT	fc	PunctType=Comm	19	punct	19:punct	_
# 18	pues	pues	SCONJ	cs	_	19	mark	19:mark	_
# 18.1	_	_	PRON	p	_	_	_	19:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTAA200007042484c7--1-CorefType:ident,gstype:gen)
# 19	quedaron	quedar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	3	advcl	3:advcl	ArgTem=argM:adv
# 20	con	con	ADP	sps00	_	22	case	22:case	_
# 21	mucho	mucho	DET	di0ms0	Gender=Masc|Number=Sing|NumType=Card|PronType=Ind	22	det	22:det	Entity=(CESSCASTAA200007042484c8--2-gstype:gen
# 22	grano	grano	NOUN	ncms000	Gender=Masc|Number=Sing	19	obl:arg	19:obl:arg	ArgTem=arg2:atr
# 23	almacenado	almacenado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	22	amod	22:amod	SpaceAfter=No
# 24	,	,	PUNCT	fc	PunctType=Comm	26	punct	26:punct	_
# 25	que	que	PRON	pr0cn000	PronType=Rel	28	obj	28:obj	ArgTem=arg1:pat|Entity=(CESSCASTAA200007042484c8--1-CorefType:ident,gstype:gen)
# 25.1	_	_	PRON	p	_	_	_	26:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c7--1-CorefType:ident,gstype:gen)
# 26	tuvieron	tener	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	22	acl	22:acl	_
# 27	que	que	SCONJ	cs	_	28	cc	28:cc	_
# 28	vender	vender	VERB	vmn0000	VerbForm=Inf	26	conj	26:conj	_
# 29	a	a	ADP	sps00	_	31	case	31:case	_
# 30	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 31	valor	valor	NOUN	ncms000	Gender=Masc|Number=Sing	28	obl	28:obl	ArgTem=argM:adv
# 32	muy	mucho	ADV	rg	_	33	advmod	33:advmod	_
# 33	inferior	inferior	ADJ	aq0cs0	Number=Sing	31	amod	31:amod	_
# 34-35	al	_	_	_	_	_	_	_	_
# 34	a	a	ADP	spcms	_	37	case	37:case	_
# 35	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	37	det	37:det	_
# 36	de	de	ADP	sps00	_	37	case	37:case	Entity=(NOCOREF:Gen--2-gstype:gen
# 37	compra	compra	NOUN	ncfs000	Gender=Fem|Number=Sing	33	nmod	33:nmod	SpaceAfter=No|Entity=NOCOREF:Gen)NOCOREF:Gen)CESSCASTAA200007042484c8)
# 38	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 39	explicó	explicar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 40	Echeverría	Echeverría	PROPN	np00000	_	39	nsubj	39:nsubj	SpaceAfter=No|ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 41	.	.	PUNCT	fp	PunctType=Peri	39	punct	39:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s5
# # text = Añadió que los exportadores pidieron un aval del Estado por 22 millones de dólares para afrontar la crisis, pero el Instituto Hondureño del Café (IHCAFE), que maneja la política del sector, rechazó tal pretensión.
# 0.1	_	_	PRON	p	_	_	_	1:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 1	Añadió	añadir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 2	que	que	SCONJ	cs	_	5	mark	5:mark	_
# 3	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	4	det	4:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 4	exportadores	exportador	NOUN	ncmp000	Gender=Masc|Number=Plur	5	nsubj	5:nsubj	ArgTem=arg0:agt|Entity=NOCOREF:Gen)
# 5	pidieron	pedir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	1	ccomp	1:ccomp	ArgTem=arg1:pat
# 6	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	7	det	7:det	Entity=(CESSCASTAA200007042484c10--2-gstype:gen
# 7	aval	aval	NOUN	ncms000	Gender=Masc|Number=Sing	5	obj	5:obj	ArgTem=arg1:pat
# 8-9	del	_	_	_	_	_	_	_	_
# 8	de	de	ADP	spcms	_	10	case	10:case	_
# 9	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	10	det	10:det	_
# 10	Estado	Estado	PROPN	np00000	_	7	nmod	7:nmod	Entity=(CESSCASTAA200007042484c12-organization-1-gstype:spec)
# 11	por	por	ADP	sps00	_	13	case	13:case	_
# 12	22	22	NUM	_	NumForm=Digit|NumType=Card	13	nummod	13:nummod	Entity=(NOCOREF:Spec.number-number-2-gstype:spec
# 13	millones	millón	NOUN	ncmp000	Gender=Masc|Number=Plur	7	nmod	7:nmod	_
# 14	de	de	ADP	sps00	_	15	case	15:case	_
# 15	dólares	dólar	NOUN	zm	Gender=Masc|Number=Plur	13	nmod	13:nmod	Currency=Yes|Entity=(NOCOREF:Spec.number-number-1-gstype:spec)NOCOREF:Spec.number)CESSCASTAA200007042484c10)
# 16	para	para	ADP	sps00	_	17	mark	17:mark	_
# 17	afrontar	afrontar	VERB	vmn0000	VerbForm=Inf	5	advcl	5:advcl	ArgTem=argM:fin
# 18	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	19	det	19:det	Entity=(CESSCASTAA200007042484c11--2-CorefType:ident,gstype:gen
# 19	crisis	crisis	NOUN	ncfn000	Gender=Fem	17	obj	17:obj	SpaceAfter=No|ArgTem=arg1:pat|Entity=CESSCASTAA200007042484c11)
# 20	,	,	PUNCT	fc	PunctType=Comm	40	punct	40:punct	_
# 21	pero	pero	CCONJ	cc	_	40	cc	40:cc	_
# 22	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	23	det	23:det	Entity=(CESSCASTAA200007042484c9-organization-2-gstype:spec
# 23	Instituto	Instituto	PROPN	np00000	_	40	nsubj	40:nsubj	MWE=Instituto_Hondureño_del_Café|MWEPOS=PROPN|ArgTem=arg0:cau
# 24	Hondureño	Hondureño	PROPN	_	_	23	flat	23:flat	_
# 25-26	del	_	_	_	_	_	_	_	_
# 25	de	de	ADP	_	_	27	case	27:case	_
# 26	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	27	det	27:det	_
# 27	Café	Café	PROPN	_	_	23	flat	23:flat	_
# 28	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	29	punct	29:punct	SpaceAfter=No|Entity=(CESSCASTAA200007042484c9-organization-2-CorefType:pred.definit,gstype:spec
# 29	IHCAFE	IHCAFE	PROPN	np00000	_	23	flat	23:flat	SpaceAfter=No
# 30	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	29	punct	29:punct	SpaceAfter=No|Entity=CESSCASTAA200007042484c9)
# 31	,	,	PUNCT	fc	PunctType=Comm	33	punct	33:punct	_
# 32	que	que	PRON	pr0cn000	PronType=Rel	33	nsubj	33:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c9-organization-1-CorefType:ident,gstype:spec)
# 33	maneja	manejar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	23	acl	23:acl	_
# 34	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	35	det	35:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 35	política	política	NOUN	ncfs000	Gender=Fem|Number=Sing	33	obj	33:obj	ArgTem=arg1:pat
# 36-37	del	_	_	_	_	_	_	_	_
# 36	de	de	ADP	spcms	_	38	case	38:case	_
# 37	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	38:det	_
# 38	sector	sector	NOUN	ncms000	Gender=Masc|Number=Sing	35	nmod	35:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007042484c14--1-gstype:gen,HomoDD)NOCOREF:Gen)
# 39	,	,	PUNCT	fc	PunctType=Comm	33	punct	33:punct	Entity=CESSCASTAA200007042484c9)
# 40	rechazó	rechazar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	5	conj	5:conj	_
# 41	tal	tal	DET	dd0cs0	Number=Sing|PronType=Dem	42	det	42:det	Entity=(CESSCASTAA200007042484c10--2-CorefType:ident,gstype:gen
# 42	pretensión	pretensión	NOUN	ncfs000	Gender=Fem|Number=Sing	40	obj	40:obj	SpaceAfter=No|ArgTem=arg1:tem|Entity=CESSCASTAA200007042484c10)
# 43	.	.	PUNCT	fp	PunctType=Peri	1	punct	1:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s6
# # text = "Las empresas que murieron durante la crisis ya no se pueden recuperar", lamentó, y exhortó al Gobierno a promover más el café hondureño en el mercado internacional para impulsar una recuperación del sector, el principal de la economía del país.
# 1	"	"	PUNCT	fe	PunctType=Quot	16	punct	16:punct	SpaceAfter=No
# 2	Las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	3	det	3:det	Entity=(CESSCASTAA200007042484c2--2-CorefType:ident,gstype:gen
# 3	empresas	empresa	NOUN	ncfp000	Gender=Fem|Number=Plur	16	nsubj	16:nsubj	ArgTem=arg1:pat
# 4	que	que	PRON	pr0cn000	PronType=Rel	5	nsubj	5:nsubj	ArgTem=arg1:tem|Entity=(CESSCASTAA200007042484c2--1-CorefType:ident,gstype:gen)
# 5	murieron	morir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	3	acl	3:acl	_
# 6	durante	durante	ADP	sps00	_	8	case	8:case	_
# 7	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	8:det	Entity=(CESSCASTAA200007042484c11--2-CorefType:ident,gstype:gen
# 8	crisis	crisis	NOUN	ncfn000	Gender=Fem	5	obl	5:obl	ArgTem=argM:tmp|Entity=CESSCASTAA200007042484c11)CESSCASTAA200007042484c2)
# 9	ya	ya	ADV	rg	_	13	advmod	13:advmod	ArgTem=argM:tmp
# 10	no	no	ADV	rn	Polarity=Neg	13	advmod	13:advmod	_
# 11	se	él	PRON	p0000000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	13	expl:pv	13:expl:pv	_
# 12	pueden	poder	AUX	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	13	aux	13:aux	_
# 13	recuperar	recuperar	VERB	vmn0000	VerbForm=Inf	16	xcomp	16:xcomp	SpaceAfter=No|ArgTem=arg1:pat
# 14	"	"	PUNCT	fe	PunctType=Quot	13	punct	13:punct	SpaceAfter=No
# 15	,	,	PUNCT	fc	PunctType=Comm	13	punct	13:punct	_
# 16	lamentó	lamentar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	SpaceAfter=No
# 16.1	_	_	PRON	p	_	_	_	16:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 17	,	,	PUNCT	fc	PunctType=Comm	19	punct	19:punct	_
# 18	y	y	CCONJ	cc	_	19	cc	19:cc	_
# 18.1	_	_	PRON	p	_	_	_	19:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 19	exhortó	exhortar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	16	conj	16:conj	_
# 20-21	al	_	_	_	_	_	_	_	_
# 20	a	a	ADP	spcms	_	22	case	22:case	_
# 21	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	22	det	22:det	_
# 22	Gobierno	Gobierno	PROPN	np00000	_	19	obl:arg	19:obl:arg	ArgTem=arg1:pat|Entity=(CESSCASTAA200007042484c12-organization-1-CorefType:ident,gstype:spec)
# 23	a	a	ADP	sps00	_	24	mark	24:mark	_
# 24	promover	promover	VERB	vmn0000	VerbForm=Inf	19	xcomp	19:xcomp	ArgTem=arg2:tem
# 25	más	más	ADV	rg	Degree=Cmp	24	advmod	24:advmod	ArgTem=argM:adv
# 26	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	27	det	27:det	Entity=(CESSCASTAA200007042484c16-other-2-gstype:spec
# 27	café	café	NOUN	ncms000	Gender=Masc|Number=Sing	24	obj	24:obj	ArgTem=arg1:pat
# 28	hondureño	hondureño	ADJ	aq0ms0	Gender=Masc|Number=Sing	27	amod	27:amod	Entity=CESSCASTAA200007042484c16)
# 29	en	en	ADP	sps00	_	31	case	31:case	_
# 30	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	Entity=(CESSCASTAA200007042484c13--2-CorefType:ident,gstype:gen,HomoDD
# 31	mercado	mercado	NOUN	ncms000	Gender=Masc|Number=Sing	24	obl	24:obl	ArgTem=argM:loc
# 32	internacional	internacional	ADJ	aq0cs0	Number=Sing	31	amod	31:amod	Entity=CESSCASTAA200007042484c13)
# 33	para	para	ADP	sps00	_	34	mark	34:mark	_
# 34	impulsar	impulsar	VERB	vmn0000	VerbForm=Inf	24	advcl	24:advcl	ArgTem=argM:adv
# 35	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	36	det	36:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 36	recuperación	recuperación	NOUN	ncfs000	Gender=Fem|Number=Sing	34	obj	34:obj	ArgTem=arg1:pat
# 37-38	del	_	_	_	_	_	_	_	_
# 37	de	de	ADP	spcms	_	39	case	39:case	_
# 38	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	39	det	39:det	_
# 39	sector	sector	NOUN	ncms000	Gender=Masc|Number=Sing	36	nmod	36:nmod	SpaceAfter=No|ArgTem=arg1:tem|Entity=(CESSCASTAA200007042484c14--1-CorefType:ident,gstype:gen,HomoDD
# 40	,	,	PUNCT	fc	PunctType=Comm	42	punct	42:punct	Entity=(CESSCASTAA200007042484c14--3-CorefType:pred.definit,gstype:gen
# 41	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	42	det	42:det	_
# 42	principal	principal	ADJ	aq0cs0	Number=Sing	39	appos	39:appos	_
# 43	de	de	ADP	sps00	_	45	case	45:case	_
# 44	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	45	det	45:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 45	economía	economía	NOUN	ncfs000	Gender=Fem|Number=Sing	42	nmod	42:nmod	_
# 46-47	del	_	_	_	_	_	_	_	_
# 46	de	de	ADP	spcms	_	48	case	48:case	_
# 47	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	48	det	48:det	_
# 48	país	país	NOUN	ncms000	Gender=Masc|Number=Sing	45	nmod	45:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007042484c15-place-1-CorefType:ident,gstype:spec)NOCOREF:Gen)CESSCASTAA200007042484c14)CESSCASTAA200007042484c14)NOCOREF:Gen)
# 49	.	.	PUNCT	fp	PunctType=Peri	16	punct	16:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s7
# # text = Las exportaciones de café hondureño en la cosecha 1999-2000, de unos 3,5 millones de sacos de 46 kilos, alcanzaron unos 300 millones de dólares hasta Junio pasado.
# 1	Las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	2	det	2:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 2	exportaciones	exportación	NOUN	ncfp000	Gender=Fem|Number=Plur	21	nsubj	21:nsubj	ArgTem=arg0:agt
# 3	de	de	ADP	sps00	_	4	case	4:case	_
# 4	café	café	NOUN	ncms000	Gender=Masc|Number=Sing	2	nmod	2:nmod	ArgTem=arg1:pat|Entity=(CESSCASTAA200007042484c16-other-1-CorefType:ident,gstype:spec
# 5	hondureño	hondureño	ADJ	aq0ms0	Gender=Masc|Number=Sing	4	amod	4:amod	Entity=CESSCASTAA200007042484c16)
# 6	en	en	ADP	sps00	_	8	case	8:case	_
# 7	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	8:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 8	cosecha	cosecha	NOUN	ncfs000	Gender=Fem|Number=Sing	2	nmod	2:nmod	ArgTem=arg1:pat,argM:tmp
# 9	1999-2000	1999-2000	NOUN	_	AdvType=Tim	8	appos	8:appos	SpaceAfter=No|ArgTem=argM:tmp|Entity=(NOCOREF:Spec.date-time-1-gstype:spec)NOCOREF:Gen)
# 10	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	_
# 11	de	de	ADP	sps00	_	14	case	14:case	_
# 12	unos	uno	PRON	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	13	nmod	13:nmod	Entity=(NOCOREF:Gen--3-gstype:gen
# 13	3,5	3.5	NUM	_	NumForm=Digit|NumType=Card	14	nummod	14:nummod	_
# 14	millones	millón	NOUN	ncmp000	Gender=Masc|Number=Plur	2	nmod	2:nmod	_
# 15	de	de	ADP	sps00	_	16	case	16:case	_
# 16	sacos	saco	NOUN	ncmp000	Gender=Masc|Number=Plur	14	nmod	14:nmod	_
# 17	de	de	ADP	sps00	_	19	case	19:case	_
# 18	46	46	NUM	_	NumForm=Digit|NumType=Card	19	nummod	19:nummod	Entity=(NOCOREF:Spec.number-number-2-gstype:spec
# 19	kilos	kilo	NOUN	ncmp000	Gender=Masc|Number=Plur	16	nmod	16:nmod	SpaceAfter=No|Entity=NOCOREF:Spec.number)NOCOREF:Gen)
# 20	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	Entity=NOCOREF:Gen)
# 21	alcanzaron	alcanzar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 22	unos	uno	PRON	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	23	nmod	23:nmod	Entity=(NOCOREF:Spec.number-number-3-gstype:spec
# 23	300	300	NUM	_	NumForm=Digit|NumType=Card	24	nummod	24:nummod	_
# 24	millones	millón	NOUN	ncmp000	Gender=Masc|Number=Plur	21	obj	21:obj	ArgTem=arg1:pat
# 25	de	de	ADP	sps00	_	26	case	26:case	_
# 26	dólares	dólar	NOUN	zm	Gender=Masc|Number=Plur	24	nmod	24:nmod	Currency=Yes|Entity=(NOCOREF:Spec.number-number-1-gstype:spec)NOCOREF:Spec.number)
# 27	hasta	hasta	ADP	sps00	_	28	case	28:case	_
# 28	Junio	Junio	NOUN	_	AdvType=Tim	21	obl	21:obl	ArgTem=argM:tmp|Entity=(NOCOREF:Spec.date-time-1-gstype:spec
# 29	pasado	pasado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	28	amod	28:amod	SpaceAfter=No|Entity=NOCOREF:Spec.date)
# 30	.	.	PUNCT	fp	PunctType=Peri	21	punct	21:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s8
# # text = Honduras retendrá parte de su cosecha exportable en el nuevo ciclo, como determinaron los países exportadores en Mayo pasado en Londres, para estimular la subida del precio internacional del café, cuyo cultivo está en manos de unos 80.000 productores locales.
# 1	Honduras	Honduras	PROPN	np00000	_	2	nsubj	2:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA200007042484c18-organization-1-gstype:spec)
# 2	retendrá	retener	VERB	vmif3s0	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	0	root	0:root	_
# 3	parte	parte	NOUN	ncfs000	Gender=Fem|Number=Sing	2	obj	2:obj	ArgTem=arg1:pat|Entity=(NOCOREF:Gen--1-gstype:gen
# 4	de	de	ADP	sps00	_	6	case	6:case	_
# 5	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	6	det	6:det	ArgTem=arg0:agt|Entity=(NOCOREF:Gen--2-gstype:gen(CESSCASTAA200007042484c18-organization-1-CorefType:ident,gstype:spec)
# 6	cosecha	cosecha	NOUN	ncfs000	Gender=Fem|Number=Sing	3	nmod	3:nmod	ArgTem=arg1:pat
# ...
# 1	Los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	2	det	2:det	Entity=(CESSCASTAA2000112620778c7--3-gstype:gen,HomoDD
# 2	1.300	1300	NUM	_	NumForm=Digit|NumType=Card	3	nummod	3:nummod	_
# 3	atletas	atleta	NOUN	nccp000	Number=Plur	5	nsubj	5:nsubj	ArgTem=arg1:tem
# 4	participantes	participante	ADJ	aq0cp0	Number=Plur	3	amod	3:amod	Entity=CESSCASTAA2000112620778c7)
# 5	tuvieron	tener	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 6	ante	ante	ADP	sps00	_	7	case	7:case	_
# 7	sí	él	PRON	pp3cno00	Case=Acc|Person=3|PrepCase=Pre|PronType=Prs|Reflex=Yes	5	obl	5:obl	ArgTem=argM:loc|Entity=(CESSCASTAA2000112620778c7--1-CorefType:ident,gstype:gen)
# 8	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	10	det	10:det	Entity=(NOCOREF:Gen--3-gstype:gen(CESSCASTAA2000112620778c8--3-gstype:gen
# 9	espléndido	espléndido	ADJ	aq0ms0	Gender=Masc|Number=Sing	10	amod	10:amod	_
# 10	recorrido	recorrido	NOUN	ncms000	Gender=Masc|Number=Sing	5	obj	5:obj	ArgTem=arg2:atr|Entity=CESSCASTAA2000112620778c8)|SpaceAfter=No
# 11	,	,	PUNCT	fc	PunctType=Comm	13	punct	13:punct	_
# 12	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	13	det	13:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 13	respeto	respeto	NOUN	ncms000	Gender=Masc|Number=Sing	10	appos	10:appos	_
# 14	de	de	ADP	sps00	_	16	case	16:case	_
# 15	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	16	det	16:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 16	lluvia	lluvia	NOUN	ncfs000	Gender=Fem|Number=Sing	13	nmod	13:nmod	_
# 17	-	-	PUNCT	fg	PunctType=Dash	18	punct	18:punct	_
# 18	amenazante	amenazante	ADJ	aq0cs0	Number=Sing	16	amod	16:amod	_
# 19	días	día	NOUN	ncmp000	Gender=Masc|Number=Plur	18	obj	18:obj	_
# 20	pasados	pasado	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	19	amod	19:amod	_
# 21	-	-	PUNCT	fg	PunctType=Dash	18	punct	18:punct	SpaceAfter=No|Entity=NOCOREF:Gen)NOCOREF:Gen)
# 22	,	,	PUNCT	fc	PunctType=Comm	24	punct	24:punct	_
# 23	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	24	det	24:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 24	temperatura	temperatura	NOUN	ncfs000	Gender=Fem|Number=Sing	10	appos	10:appos	_
# 25	entre	entre	ADP	sps00	_	29	case	29:case	_
# 26	15	15	NUM	_	NumForm=Digit|NumType=Card	29	nummod	29:nummod	Entity=(NOCOREF:Spec.number-number-4-gstype:spec
# 27	y	y	CCONJ	cc	_	28	cc	28:cc	_
# 28	17	17	NUM	_	NumForm=Digit|NumType=Card	26	conj	26:conj	_
# 29	grados	grado	NOUN	ncmp000	Gender=Masc|Number=Plur	24	nmod	24:nmod	SpaceAfter=No|Entity=NOCOREF:Spec.number)
# 30	,	,	PUNCT	fc	PunctType=Comm	33	punct	33:punct	_
# 31	aunque	aunque	SCONJ	cs	_	33	mark	33:mark	_
# 32	con	con	ADP	sps00	_	33	case	33:case	_
# 33	algo	algo	PRON	pi0cs000	Number=Sing|PronType=Ind	24	nmod	24:nmod	Entity=(NOCOREF:Gen--1-gstype:gen
# 34	de	de	ADP	sps00	_	35	case	35:case	_
# 35	viento	viento	NOUN	ncms000	Gender=Masc|Number=Sing	33	nmod	33:nmod	_
# 36	molesto	molesto	ADJ	aq0ms0	Gender=Masc|Number=Sing	35	amod	35:amod	Entity=NOCOREF:Gen)
# 37	en	en	ADP	sps00	_	38	case	38:case	_
# 38	zonas	zona	NOUN	ncfp000	Gender=Fem|Number=Plur	33	nmod	33:nmod	Entity=(NOCOREF:Gen--1-gstype:gen
# 39	determinadas	determinado	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	38	amod	38:amod	_
# 40-41	del	_	_	_	_	_	_	_	_
# 40	de	de	ADP	spcms	_	42	case	42:case	_
# 41	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	42	det	42:det	_
# 42	recorrido	recorrido	NOUN	ncms000	Gender=Masc|Number=Sing	38	nmod	38:nmod	Entity=(CESSCASTAA2000112620778c8--1-CorefType:ident,gstype:gen)NOCOREF:Gen)NOCOREF:Gen)
# 43	y	y	CCONJ	cc	_	49	cc	49:cc	SpaceAfter=No
# 44	,	,	PUNCT	fc	PunctType=Comm	45	punct	45:punct	_
# 45	eso	eso	NOUN	rg	_	49	advmod	49:advmod	MWE=eso_sí|MWEPOS=ADV
# 46	sí	sí	NOUN	_	_	45	fixed	45:fixed	SpaceAfter=No
# 47	,	,	PUNCT	fc	PunctType=Comm	45	punct	45:punct	_
# 48	alto	alto	ADJ	aq0ms0	Gender=Masc|Number=Sing	49	amod	49:amod	Entity=(NOCOREF:Gen--2-gstype:gen
# 49	porcentaje	porcentaje	NOUN	ncms000	Gender=Masc|Number=Sing	10	conj	10:conj	_
# 50	de	de	ADP	sps00	_	51	case	51:case	_
# 51	humedad	humedad	NOUN	ncfs000	Gender=Fem|Number=Sing	49	nmod	49:nmod	SpaceAfter=No|Entity=NOCOREF:Gen)NOCOREF:Gen)
# 52	.	.	PUNCT	fp	PunctType=Peri	5	punct	5:punct	_
#
#
# # sent_id = CESS-CAST-AA-20001126-20778-s7
# # text = Sólo los tres hombres del podio, los auténticos protagonistas del maratón, terminaron en tiempos de cierto reconocimiento, ya que el cuarto - Wesley Chelule, de Kenia, anunciado con una mejor marca de 2.10:14-, completó el circuito de 42,195 kms. en 2.16:44.
# 1	Sólo	sólo	ADV	rg	_	4	advmod	4:advmod	_
# 2	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	4	det	4:det	Entity=(CESSCASTAA2000112620778c9--3-gstype:gen,HomoDD
# 3	tres	tres	NUM	dn0cp0	Number=Plur|NumForm=Word|NumType=Card	2	nummod	2:nummod	_
# 4	hombres	hombre	NOUN	ncmp000	Gender=Masc|Number=Plur	16	nsubj	16:nsubj	ArgTem=arg1:tem
# 5-6	del	_	_	_	_	_	_	_	_
# 5	de	de	ADP	spcms	_	7	case	7:case	_
# 6	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	7	det	7:det	_
# 7	podio	podio	NOUN	ncms000	Gender=Masc|Number=Sing	4	nmod	4:nmod	SpaceAfter=No|Entity=(NOCOREF:Gen--1-gstype:gen,HomoDD)
# 8	,	,	PUNCT	fc	PunctType=Comm	11	punct	11:punct	Entity=(CESSCASTAA2000112620778c9--4-CorefType:pred.definit,gstype:gen
# 9	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	11	det	11:det	_
# 10	auténticos	auténtico	ADJ	aq0mp0	Gender=Masc|Number=Plur	11	amod	11:amod	_
# 11	protagonistas	protagonista	NOUN	nccp000	Number=Plur	4	appos	4:appos	_
# 12-13	del	_	_	_	_	_	_	_	_
# 12	de	de	ADP	spcms	_	14	case	14:case	_
# 13	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	14	det	14:det	_
# 14	maratón	maratón	NOUN	ncms000	Gender=Masc|Number=Sing	11	nmod	11:nmod	SpaceAfter=No|Entity=(CESSCASTAA2000112620778c2-other-1-CorefType:ident,gstype:spec)
# 15	,	,	PUNCT	fc	PunctType=Comm	11	punct	11:punct	Entity=CESSCASTAA2000112620778c9)CESSCASTAA2000112620778c9)
# 16	terminaron	terminar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 17	en	en	ADP	sps00	_	18	case	18:case	_
# 18	tiempos	tiempo	NOUN	ncmp000	Gender=Masc|Number=Plur	16	obl	16:obl	ArgTem=argM:tmp|Entity=(NOCOREF:Gen--1-gstype:gen
# 19	de	de	ADP	sps00	_	21	case	21:case	_
# 20	cierto	cierto	DET	di0ms0	Gender=Masc|Number=Sing|PronType=Ind	21	det	21:det	_
# 21	reconocimiento	reconocimiento	NOUN	ncms000	Gender=Masc|Number=Sing	18	nmod	18:nmod	SpaceAfter=No|Entity=NOCOREF:Gen)
# 22	,	,	PUNCT	fc	PunctType=Comm	42	punct	42:punct	_
# 23	ya	ya	ADV	cs	_	42	mark	42:mark	MWE=ya_que|MWEPOS=SCONJ
# 24	que	que	SCONJ	_	_	23	fixed	23:fixed	_
# 25	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	26	det	26:det	Entity=(NOCOREF:Spec.person-person-2-gstype:spec
# 26	cuarto	cuarto	NOUN	ncms000	Gender=Masc|Number=Sing	42	nsubj	42:nsubj	ArgTem=arg0:agt
# 27	-	-	PUNCT	fg	PunctType=Dash	28	punct	28:punct	Entity=(NOCOREF:Spec.person-person-2-gstype:spec
# 28	Wesley	Wesley	PROPN	np00000	_	26	appos	26:appos	MWE=Wesley_Chelule|MWEPOS=PROPN
# 29	Chelule	Chelule	PROPN	_	_	28	flat	28:flat	SpaceAfter=No
# 30	,	,	PUNCT	fc	PunctType=Comm	28	punct	28:punct	Entity=NOCOREF:Spec.person)
# 31	de	de	ADP	sps00	_	32	case	32:case	_
# 32	Kenia	Kenia	PROPN	np00000	_	26	nmod	26:nmod	SpaceAfter=No|Entity=(NOCOREF:Spec.location-place-1-gstype:spec)
# 33	,	,	PUNCT	fc	PunctType=Comm	34	punct	34:punct	_
# 34	anunciado	anunciado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	26	amod	26:amod	_
# 35	con	con	ADP	sps00	_	38	case	38:case	_
# 36	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	38	det	38:det	Entity=(NOCOREF:Gen--3-gstype:gen
# 37	mejor	mejor	ADJ	aq0cs0	Degree=Cmp|Number=Sing	38	amod	38:amod	_
# 38	marca	marca	NOUN	ncfs000	Gender=Fem|Number=Sing	34	obl	34:obl	ArgTem=argM:adv
# 39	de	de	ADP	sps00	_	40	case	40:case	_
# 40	2.10:14-	2.10:14	NUM	_	NumForm=Digit|NumType=Card	38	nummod	38:nummod	SpaceAfter=No|Entity=(NOCOREF:Spec.number-number-1-gstype:spec)NOCOREF:Gen)
# 41	,	,	PUNCT	fc	PunctType=Comm	34	punct	34:punct	Entity=NOCOREF:Spec.person)
# 42	completó	completar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	16	advcl	16:advcl	ArgTem=argM:cau
# 43	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	44	det	44:det	Entity=(CESSCASTAA2000112620778c8--2-CorefType:ident,gstype:gen
# 44	circuito	circuito	NOUN	ncms000	Gender=Masc|Number=Sing	42	obj	42:obj	ArgTem=arg1:pat
# 45	de	de	ADP	sps00	_	47	case	47:case	_
# 46	42,195	42.195	NUM	_	NumForm=Digit|NumType=Card	47	nummod	47:nummod	Entity=(NOCOREF:Spec.number-number-2-gstype:spec
# 47	kms.	km	NUM	zu	NumForm=Digit|NumType=Card	44	nummod	44:nummod	Entity=NOCOREF:Spec.number)CESSCASTAA2000112620778c8)
# 48	en	en	ADP	sps00	_	49	case	49:case	_
# 49	2.16:44	2.16:44	NUM	_	NumForm=Digit|NumType=Card	42	obl	42:obl	SpaceAfter=No|ArgTem=argM:tmp|Entity=(NOCOREF:Spec.number-number-1-gstype:spec)
# 50	.	.	PUNCT	fp	PunctType=Peri	16	punct	16:punct	_
#
#
# # sent_id = CESS-CAST-AA-20001126-20778-s8
# # text = Antes del fracaso colectivo de los africanos, el décimo en la llegada al estadio de Anoeta se fue a un `redondo` 2 horas y 22 minutos, las liebres seleccionadas cumplieron bien su papel.
# 1	Antes	antes	ADV	rg	_	21	advmod	21:advmod	ArgTem=argM:tmp
# 2-3	del	_	_	_	_	_	_	_	_
# 2	de	de	ADP	spcms	_	4	case	4:case	_
# 3	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	4	det	4:det	_
# 4	fracaso	fracaso	NOUN	ncms000	Gender=Masc|Number=Sing	1	obl	1:obl	Entity=(NOCOREF:Gen--1-gstype:gen,HomoDD
# 5	colectivo	colectivo	ADJ	aq0ms0	Gender=Masc|Number=Sing	4	amod	4:amod	_
# 6	de	de	ADP	sps00	_	8	case	8:case	_
# 7	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	8	det	8:det	Entity=(NOCOREF:Gen--2-gstype:gen
# 8	africanos	africano	NOUN	ncmp000	Gender=Masc|Number=Plur	4	nmod	4:nmod	SpaceAfter=No|ArgTem=arg0:agt|Entity=NOCOREF:Gen)NOCOREF:Gen)
# 9	,	,	PUNCT	fc	PunctType=Comm	1	punct	1:punct	_
# 10	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	11	det	11:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 11	décimo	décimo	NOUN	ncms000	Gender=Masc|Number=Sing	21	nsubj	21:nsubj	ArgTem=arg0:agt
# 12	en	en	ADP	sps00	_	14	case	14:case	_
# 13	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	14	det	14:det	Entity=(NOCOREF:Gen--2-gstype:gen,HomoDD
# 14	llegada	llegada	NOUN	ncfs000	Gender=Fem|Number=Sing	11	nmod	11:nmod	_
# 15-16	al	_	_	_	_	_	_	_	_
# 15	a	a	ADP	spcms	_	17	case	17:case	_
# 16	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	17:det	_
# 17	estadio	estadio	NOUN	ncms000	Gender=Masc|Number=Sing	14	nmod	14:nmod	ArgTem=arg4:des|Entity=(NOCOREF:Spec.location-place-1-gstype:spec
# 18	de	de	ADP	sps00	_	19	case	19:case	_
# 19	Anoeta	Anoeta	PROPN	np00000	_	17	nmod	17:nmod	Entity=(NOCOREF:Spec.location-place-1-gstype:spec)NOCOREF:Spec.location)NOCOREF:Gen)NOCOREF:Gen)
# 20	se	él	PRON	p0300000	Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	21	expl:pv	21:expl:pv	_
# 21	fue	ir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 22	a	a	ADP	sps00	_	25	case	25:case	_
# 23	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	25	det	25:det	Entity=(NOCOREF:Spec.number-number-3-gstype:spec
# 24	`redondo`	redondo	ADJ	aq0ms0	Gender=Masc|Number=Sing	25	amod	25:amod	_
# 25	2	2	NUM	w	NumForm=Digit|NumType=Card	21	obl	21:obl	MWE=2_horas_y_22_minutos|MWEPOS=NOUN|ArgTem=argM:tmp
# 26	horas	horas	NOUN	_	_	25	compound	25:compound	_
# 27	y	y	CCONJ	_	_	25	compound	25:compound	_
# 28	22	22	NUM	_	NumForm=Digit|NumType=Card	25	compound	25:compound	_
# 29	minutos	minutos	NOUN	_	_	25	compound	25:compound	SpaceAfter=No|Entity=NOCOREF:Spec.number)
# 30	,	,	PUNCT	fc	PunctType=Comm	21	punct	21:punct	_
# 31	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	32	det	32:det	Entity=(CESSCASTAA2000112620778c16--2-gstype:gen,HomoDD
# 32	liebres	liebre	NOUN	ncfp000	Gender=Fem|Number=Plur	34	nsubj	34:nsubj	ArgTem=arg0:agt
# 33	seleccionadas	seleccionado	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	32	amod	32:amod	Entity=CESSCASTAA2000112620778c16)
# 34	cumplieron	cumplir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	21	advcl	21:advcl	_
# 35	bien	bien	ADV	rg	_	34	advmod	34:advmod	ArgTem=argM:adv
# 36	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	37	det	37:det	Entity=(NOCOREF:Gen--2-gstype:gen(CESSCASTAA2000112620778c16--1-CorefType:ident,gstype:gen)
# 37	papel	papel	NOUN	ncms000	Gender=Masc|Number=Sing	34	obj	34:obj	SpaceAfter=No|ArgTem=arg1:pat|Entity=NOCOREF:Gen)
# 38	.	.	PUNCT	fp	PunctType=Peri	21	punct	21:punct	_
#
#
# # sent_id = CESS-CAST-AA-20001126-20778-s9
# # text = Fue el caso del navarro Andrés Pérez Onieva, conductor de la prueba hasta aproximadamente el km.12 y de Mohamed Erraoui, de Marruecos, que pasó el medio maratón en 1.04:32.
# 1	Fue	ser	AUX	vsis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	3	cop	3:cop	_
# 2	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	3	det	3:det	_
# 3	caso	caso	NOUN	ncms000	Gender=Masc|Number=Sing	0	root	0:root	ArgTem=arg2:atr
# 4-5	del	_	_	_	_	_	_	_	_
# 4	de	de	ADP	spcms	_	6	case	6:case	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	_
# 6	navarro	navarro	NOUN	ncms000	Gender=Masc|Number=Sing	3	nmod	3:nmod	Entity=(CESSCASTAA2000112620778c12-person-1-gstype:spec
# 7	Andrés	Andrés	PROPN	np00000	_	6	appos	6:appos	MWE=Andrés_Pérez_Onieva|MWEPOS=PROPN|Entity=(NOCOREF:Spec.person-person-1-gstype:spec
# 8	Pérez	Pérez	PROPN	_	_	7	flat	7:flat	_
# 9	Onieva	Onieva	PROPN	_	_	7	flat	7:flat	SpaceAfter=No|Entity=NOCOREF:Spec.person)
# 10	,	,	PUNCT	fc	PunctType=Comm	11	punct	11:punct	Entity=(CESSCASTAA2000112620778c12-person-2-CorefType:pred.indefinit,gstype:spec
# 11	conductor	conductor	NOUN	ncms000	Gender=Masc|Number=Sing	6	appos	6:appos	_
# 12	de	de	ADP	sps00	_	14	case	14:case	_
# 13	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	14	det	14:det	Entity=(CESSCASTAA2000112620778c2-other-2-CorefType:ident,gstype:spec
# 14	prueba	prueba	NOUN	ncfs000	Gender=Fem|Number=Sing	11	nmod	11:nmod	Entity=CESSCASTAA2000112620778c2)
# 15	hasta	hasta	ADP	sps00	_	18	case	18:case	_
# 16	aproximadamente	aproximadamente	ADV	rg	_	18	advmod	18:advmod	_
# 17	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	18	det	18:det	Entity=(NOCOREF:Spec.number-number-2-gstype:spec
# 18	km.12	12	SYM	_	_	11	nummod	11:nummod	Entity=NOCOREF:Spec.number)CESSCASTAA2000112620778c12)CESSCASTAA2000112620778c12)
# 19	y	y	CCONJ	cc	_	21	cc	21:cc	_
# 20	de	de	ADP	sps00	_	21	case	21:case	_
# 21	Mohamed	Mohamed	PROPN	np00000	_	6	conj	6:conj	MWE=Mohamed_Erraoui|MWEPOS=PROPN|Entity=(CESSCASTAA2000112620778c13-person-1-gstype:spec
# 22	Erraoui	Erraoui	PROPN	_	_	21	flat	21:flat	SpaceAfter=No
# 23	,	,	PUNCT	fc	PunctType=Comm	25	punct	25:punct	_
# 24	de	de	ADP	sps00	_	25	case	25:case	_
# 25	Marruecos	Marruecos	PROPN	np00000	_	21	nmod	21:nmod	SpaceAfter=No|Entity=(NOCOREF:Spec.location-place-1-gstype:spec)
# 26	,	,	PUNCT	fc	PunctType=Comm	25	punct	25:punct	_
# 27	que	que	PRON	pr0cn000	PronType=Rel	28	nsubj	28:nsubj	ArgTem=arg0:agt|Entity=(CESSCASTAA2000112620778c13-person-1-CorefType:ident,gstype:spec)
# 28	pasó	pasar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	21	acl	21:acl	_
# 29	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	Entity=(NOCOREF:Gen--3-gstype:gen,HomoDD
# 30	medio	medio	NUM	dn0ms0	Gender=Masc|Number=Sing|NumForm=Word|NumType=Card	29	nummod	29:nummod	_
# 31	maratón	maratón	NOUN	ncms000	Gender=Masc|Number=Sing	28	obj	28:obj	ArgTem=arg1:pat|Entity=NOCOREF:Gen)
# 32	en	en	ADP	sps00	_	33	case	33:case	_
# 33	1.04:32	1.04:32	NUM	_	NumForm=Digit|NumType=Card	28	obl	28:obl	SpaceAfter=No|ArgTem=argM:tmp|Entity=(NOCOREF:Spec.number-number-1-gstype:spec)CESSCASTAA2000112620778c13)
# 34	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#@title Estructura de los tokens etiquetados del corpus
tokenlist[1]
# Out:
# {'id': 2,
#  'form': 'El',
#  'lemma': 'el',
#  'upos': 'DET',
#  'xpos': 'da0ms0',
#  'feats': {'Definite': 'Def',
#   'Gender': 'Masc',
#   'Number': 'Sing',
#   'PronType': 'Art'},
#  'head': 5,
#  'deprel': 'det',
#  'deps': [('det', 5)],
#  'misc': {'Entity': '(NOCOREF:Gen--1-gstype:gen'}}

# %%
tokenlist[1]['form']+'|'+tokenlist[1]['upos']
# Out:
# 'El|DET'

# %% [markdown]
# ## Entrenamiento del modelo - Calculo de conteos:
#
# * tags (tags) `tagCountDict`: $C(tag)$
# * emisiones (word|tag) `emissionProbDict`: $C(word|tag)$
# * transiciones (tag|prevtag) `transitionDict`: $C(tag|prevtag)$

# %%
tagCountDict = defaultdict(int)
emissionDict = defaultdict(int)
transitionDict = defaultdict(int)

tagtype = 'upos'
with open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8") as data_file:
    for tokenlist in parse_incr(data_file):
        prevtag = None
        for token in tokenlist:
            # C(tag)
            tag = token[tagtype]
            tagCountDict[tag] += 1

            # C(word|tag) -> probabilidades emision
            word_tag = f"{token['form'].lower()}|{token[tagtype]}" # (word|tag)
            emissionDict[word_tag] += 1

            # C(tag|tag_previo) -> probabilidades transición
            if prevtag is not None:
                transitiontags = f"{tag}|{prevtag}"
                transitionDict[transitiontags] += 1
            prevtag = tag

#transitionDict
#emissionDict
#tagCountDict

# %% [markdown]
# ## Entrenamiento del modelo - calculo de probabilidades
# * probabilidades de transición:
# $$P(tag|prevtag) = \frac{C(prevtag, tag)}{C(prevtag)}$$
#
# * probabilidades de emisión:
#  $$P(word|tag) = \frac{C(word|tag)}{C(tag)}$$

# %%
transitionProbDict = {}  # Matriz de transición (A)
emissionProbDict = {}    # Matriz de emisión (B)

# Probabilidades de transición
for key, value in transitionDict.items():
    # Dividir la etiqueta y la etiqueta previa
    tag, prevtag = key.split('|')
    if tagCountDict[prevtag] > 0:
        # Calcular la probabilidad de transición y almacenarla en transitionProbDict
        transitionProbDict[key] = value / tagCountDict[prevtag]
    else:
        # Imprimir las combinaciones de etiquetas que tienen un recuento previo de cero
        print("Recuento previo cero para:", key)

# Probabilidades de emisión
for key, value in emissionDict.items():
    # Dividir la palabra y la etiqueta
    word, tag = key.split('|')
    if tagCountDict[tag] > 0:
        # Calcular la probabilidad de emisión y almacenarla en emissionProbDict
        emissionProbDict[key] = value / tagCountDict[tag]
    else:
        # Imprimir las combinaciones de palabra y etiqueta que tienen un recuento de etiqueta cero
        print("Recuento de etiqueta cero para:", key)

# Ejemplo de acceso a la probabilidad de transición para la etiqueta 'ADJ' dado que la etiqueta anterior es 'ADJ'
transitionProbDict['ADJ|ADJ']
# emissionProbDict
# Out:
# 0.030217452696978255

# %% [markdown]
# ## Guardar parámetros del modelo

# %%
# Guardar los diccionarios de probabilidades de transición y emisión como archivos numpy
np.save('transitionHMM.npy', transitionProbDict)
np.save('emissionHMM.npy', emissionProbDict)

# %%
# Cargar los diccionarios de probabilidades de transición y emisión desde los archivos numpy
transitionProbDict = np.load('transitionHMM.npy', allow_pickle=True).item()
emissionProbDict = np.load('emissionHMM.npy', allow_pickle=True).item()

# %%
# Ejemplo de acceso a la probabilidad de transición para la etiqueta 'ADJ' dado que la etiqueta anterior es 'ADJ'
transitionProbDict['ADJ|ADJ']
# Out:
# 0.030217452696978255

# %% [markdown]
# # Carga del modelo HMM previamente entrenado

# %%
# cargamos las probabilidades del modelo HMM
transitionProbdict = np.load('transitionHMM.npy', allow_pickle='TRUE').item()
emissionProbdict = np.load('emissionHMM.npy', allow_pickle='TRUE').item()

# %%
# Identificamos las categorías gramaticales 'upos' únicas en el corpus

stateSet = set()

for key in emissionProbDict.keys():
  stateSet.add(key.split('|')[1])

stateSet
# Out:
# {'ADJ',
#  'ADP',
#  'ADV',
#  'AUX',
#  'CCONJ',
#  'DET',
#  'INTJ',
#  'NOUN',
#  'NUM',
#  'PART',
#  'PRON',
#  'PROPN',
#  'PUNCT',
#  'SCONJ',
#  'SYM',
#  'VERB',
#  '_'}

# %%
# enumeramos las categorias con numeros para asignar a
# las columnas de la matriz de Viterbi

tagStateDict = {}

for i, state in enumerate(stateSet):
  tagStateDict[state] = i

tagStateDict
# Out:
# {'CCONJ': 0,
#  'ADJ': 1,
#  'DET': 2,
#  'NOUN': 3,
#  'PRON': 4,
#  'PUNCT': 5,
#  '_': 6,
#  'PROPN': 7,
#  'NUM': 8,
#  'PART': 9,
#  'ADV': 10,
#  'SYM': 11,
#  'AUX': 12,
#  'VERB': 13,
#  'ADP': 14,
#  'SCONJ': 15,
#  'INTJ': 16}

# %%
lista = [item for item in tagStateDict.items()]

# %%
lista
# Out:
# [('CCONJ', 0),
#  ('ADJ', 1),
#  ('DET', 2),
#  ('NOUN', 3),
#  ('PRON', 4),
#  ('PUNCT', 5),
#  ('_', 6),
#  ('PROPN', 7),
#  ('NUM', 8),
#  ('PART', 9),
#  ('ADV', 10),
#  ('SYM', 11),
#  ('AUX', 12),
#  ('VERB', 13),
#  ('ADP', 14),
#  ('SCONJ', 15),
#  ('INTJ', 16)]

# %% [markdown]
# # Distribucion inicial de estados latentes

# %%
# Calculamos distribución inicial de estados
initTagStateProb = {}  # \rho_i^{(0)}

# Inicializamos una lista vacía para almacenar las palabras del corpus
wordList = []

# Abrimos el archivo del corpus para lectura
with open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8") as data_file:
    count = 0  # Contador para la longitud del corpus

    # Iteramos sobre cada oración del corpus
    for tokenlist in parse_incr(data_file):
        count += 1
        # Obtenemos la etiqueta gramatical de la primera palabra de la oración
        tag = tokenlist[0]['upos']

        # Contamos la frecuencia de cada etiqueta gramatical como estado inicial
        initTagStateProb[tag] = initTagStateProb.get(tag, 0) + 1

# Normalizamos las frecuencias para obtener probabilidades
for key in initTagStateProb:
    initTagStateProb[key] /= count

# %%
# verificamos que la suma de las probabilidades es 1 (100%)
np.array([initTagStateProb[k] for k in initTagStateProb.keys()]).sum()
# Out:
# 1.0

# %% [markdown]
# # Construcción del algoritmo de Viterbi

# %% [markdown]
# Dada una secuencia de palabras $\{p_1, p_2, \dots, p_n \}$, y un conjunto de categorias gramaticales dadas por la convención `upos`, se considera la matriz de probabilidades de Viterbi así:
#
# $$
# \begin{array}{c c}
# \begin{array}{c c c c}
# \text{ADJ} \\
# \text{ADV}\\
# \text{PRON} \\
# \vdots \\
# {}
# \end{array}
# &
# \left[
# \begin{array}{c c c c}
# \nu_1(\text{ADJ}) & \nu_2(\text{ADJ}) & \dots  & \nu_n(\text{ADJ})\\
# \nu_1(\text{ADV}) & \nu_2(\text{ADV}) & \dots  & \nu_n(\text{ADV})\\
# \nu_1(\text{PRON}) & \nu_2(\text{PRON}) & \dots  & \nu_n(\text{PRON})\\
# \vdots & \vdots & \dots & \vdots \\ \hdashline
# p_1 & p_2 & \dots & p_n
# \end{array}
# \right]
# \end{array}
# $$
#
# Donde las probabilidades de la primera columna (para una categoria $i$) están dadas por:
#
# $$
# \nu_1(i) = \underbrace{\rho_i^{(0)}}_{\text{probabilidad inicial}} \times \underbrace{P(p_1 \vert i)}_{\text{emisión}}
# $$
#
# luego, para la segunda columna (dada una categoria $j$) serán:
#
# $$
# \nu_2(j) = \max_i \{ \nu_1(i) \times \underbrace{P(j \vert i)}_{\text{transición}} \times \underbrace{P(p_2 \vert j)}_{\text{emisión}} \}
# $$
#
# así, en general las probabilidades para la columna $t$ estarán dadas por:
#
# $$
# \nu_{t}(j) = \max_i \{ \overbrace{\nu_{t-1}(i)}^{\text{estado anterior}} \times \underbrace{P(j \vert i)}_{\text{transición}} \times \underbrace{P(p_t \vert j)}_{\text{emisión}} \}
# $$

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def ViterbiMatrix(secuencia, transitionProbDict=transitionProbDict, emissionProbDict=emissionProbDict,
                  tagStateDict=tagStateDict, initTagStateProb=initTagStateProb):
    """
    Calcula la matriz Viterbi para una secuencia dada.

    Parámetros:
        secuencia (str): La secuencia de palabras para la cual se calculará la matriz Viterbi.
        transitionProbDict (dict): Diccionario que contiene las probabilidades de transición.
        emissionProbDict (dict): Diccionario que contiene las probabilidades de emisión.
        tagStateDict (dict): Diccionario que mapea las etiquetas de estado a filas de la matriz Viterbi.
        initTagStateProb (dict): Diccionario que contiene las probabilidades iniciales de los estados.

    Retorna:
        numpy.ndarray: La matriz Viterbi calculada.
    """
    # Tokenizar la secuencia de entrada
    seq = word_tokenize(secuencia)
    num_tags = len(tagStateDict)
    viterbiProb = np.zeros((num_tags, len(seq)))  # upos tiene 17 categorías

    # Inicialización primera columna
    for key, tag_row in tagStateDict.items():
        word_tag = f"{seq[0].lower()}|{key}"
        if word_tag in emissionProbDict:
            viterbiProb[tag_row, 0] = initTagStateProb[key] * emissionProbDict[word_tag]

    # Cálculo de las siguientes columnas
    for col in range(1, len(seq)):
        for key, tag_row in tagStateDict.items():
            word_tag = f"{seq[col].lower()}|{key}"
            if word_tag in emissionProbDict:
                # Miramos estados de la columna anterior
                possible_probs = [
                    viterbiProb[tag_row2, col - 1] * transitionProbDict[f"{key2}|{key}"] * emissionProbDict[word_tag]
                    for key2, tag_row2 in tagStateDict.items()
                    if f"{key2}|{key}" in transitionProbDict and viterbiProb[tag_row2, col - 1] > 0
                ]
                viterbiProb[tag_row, col] = max(possible_probs, default=0)

    return viterbiProb

# Ejemplo de uso
matrix = ViterbiMatrix('el mundo es pequeño')
matrix
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 3.19336137e-10, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.40681635e-13],
#        [1.24339097e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 4.04259663e-06, 1.23362810e-11, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.66211053e-06, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 2.17289569e-08, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
def ViterbiTags(secuencia, transitionProbdict=transitionProbdict, emissionProbdict=emissionProbdict,
            tagStateDict=tagStateDict, initTagStateProb=initTagStateProb):
  seq = word_tokenize(secuencia)
  viterbiProb = np.zeros((17, len(seq)))  # upos tiene 17 categorias

  # inicialización primera columna
  for key in tagStateDict.keys():
    tag_row = tagStateDict[key]
    word_tag = seq[0].lower()+'|'+key
    if word_tag in emissionProbdict.keys():
      viterbiProb[tag_row, 0] = initTagStateProb[key]*emissionProbdict[word_tag]

  # computo de las siguientes columnas
  for col in range(1, len(seq)):
    for key in tagStateDict.keys():
      tag_row = tagStateDict[key]
      word_tag = seq[col].lower()+'|'+key
      if word_tag in emissionProbdict.keys():
        # miramos estados de la col anterior
        possible_probs = []
        for key2 in tagStateDict.keys():
          tag_row2 = tagStateDict[key2]
          tag_prevtag = key+'|'+key2
          if tag_prevtag in transitionProbdict.keys():
            if viterbiProb[tag_row2, col-1]>0:
              possible_probs.append(
                  viterbiProb[tag_row2, col-1]*transitionProbdict[tag_prevtag]*emissionProbdict[word_tag])
        viterbiProb[tag_row, col] = max(possible_probs)

    # contruccion de secuencia de tags
    res = []
    for i, p in enumerate(seq):
      for tag in tagStateDict.keys():
        if tagStateDict[tag] == np.argmax(viterbiProb[:, i]):
          res.append((p, tag))

  return res

ViterbiTags('el mundo es muy pequeño')
# Out:
# [('el', 'DET'),
#  ('mundo', 'NOUN'),
#  ('es', 'AUX'),
#  ('muy', 'ADV'),
#  ('pequeño', 'ADJ')]

# %%
ViterbiTags('estos instrumentos han de rasgar')
# Out:
# [('estos', 'DET'),
#  ('instrumentos', 'NOUN'),
#  ('han', 'AUX'),
#  ('de', 'ADP'),
#  ('rasgar', 'VERB')]

# %% [markdown]
# # Entrenamiento directo de HMM con NLTK
#
# * clase en python (NLTK) de HMM: https://www.nltk.org/_modules/nltk/tag/hmm.html

# %%
#@title ejemplo con el Corpus Treebank en ingles
import nltk
nltk.download('treebank')
from nltk.corpus import treebank
train_data = treebank.tagged_sents()[:3900]
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Unzipping corpora/treebank.zip.

# %%
#@title estructura de la data de entrenamiento
train_data
# Out:
# [[('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('will', 'MD'), ('join', 'VB'), ('the', 'DT'), ('board', 'NN'), ('as', 'IN'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')], [('Mr.', 'NNP'), ('Vinken', 'NNP'), ('is', 'VBZ'), ('chairman', 'NN'), ('of', 'IN'), ('Elsevier', 'NNP'), ('N.V.', 'NNP'), (',', ','), ('the', 'DT'), ('Dutch', 'NNP'), ('publishing', 'VBG'), ('group', 'NN'), ('.', '.')], ...]

# %%
#@title HMM pre-construido en NLTK
from nltk.tag import hmm
tagger = hmm.HiddenMarkovModelTrainer().train_supervised(train_data)
tagger
# Out:
# <HiddenMarkovModelTagger 46 states and 12385 output symbols>

# %%
tagger.tag("Pierre Vinken will get old".split())
# Out:
# /usr/local/lib/python3.10/dist-packages/nltk/tag/hmm.py:334: RuntimeWarning: overflow encountered in cast
#   X[i, j] = self._transitions[si].logprob(self._states[j])
# /usr/local/lib/python3.10/dist-packages/nltk/tag/hmm.py:336: RuntimeWarning: overflow encountered in cast
#   O[i, k] = self._output_logprob(si, self._symbols[k])
# /usr/local/lib/python3.10/dist-packages/nltk/tag/hmm.py:332: RuntimeWarning: overflow encountered in cast
#   P[i] = self._priors.logprob(si)
# [('Pierre', 'NNP'),
#  ('Vinken', 'NNP'),
#  ('will', 'MD'),
#  ('get', 'VB'),
#  ('old', 'JJ')]

# %%
#@title training accuracy
tagger.evaluate(treebank.tagged_sents()[:3900])
# Out:
# <ipython-input-26-36c901df877a>:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   tagger.evaluate(treebank.tagged_sents()[:3900])
# 0.9815403947224078

# %% [markdown]
# ## Ejercicio de práctica
#
# **Objetivo:** Entrena un HMM usando la clase `hmm.HiddenMarkovModelTrainer()` sobre el dataset `UD_Spanish_AnCora`.

# %% [markdown]
# 1. **Pre-procesamiento:** En el ejemplo anterior usamos el dataset en ingles `treebank`, el cual viene con una estructura diferente a la de `AnCora`, en esta parte escribe código para transformar la estructura de `AnCora` de manera que quede igual al `treebank` que usamos así:
#
# $$\left[ \left[ (\text{'El'}, \text{'DET'}), (\dots), \dots\right], \left[\dots \right] \right]$$

# %%
# desarrolla tu código aquí

# %% [markdown]
# 2. **Entrenamiento:** Una vez que el dataset esta con la estructura correcta, utiliza la clase `hmm.HiddenMarkovModelTrainer()` para entrenar con el $80 \%$ del dataset como conjunto de `entrenamiento` y $20 \%$ para el conjunto de `test`.
#
# **Ayuda:** Para la separacion entre conjuntos de entrenamiento y test, puedes usar la funcion de Scikit Learn:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# En este punto el curso de Machine Learning con Scikit Learn es un buen complemento para entender mejor las funcionalidades de Scikit Learn: https://platzi.com/cursos/scikitlearn-ml/

# %%
# desarrolla tu código aquí

# %% [markdown]
# 3. **Validación del modelo:** Un vez entrenado el `tagger`, calcula el rendimiento del modelo (usando `tagger.evaluate()`) para los conjuntos de `entrenamiento` y `test`.

# %%
#desarrolla tu código aquí

# %% [markdown]
# ## Construcción de un modelo markoviano de máxima entropía

# %%
# !pip install conllu
# !pip install stanza
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Collecting conllu
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.5.3
# Collecting stanza
#   Downloading stanza-1.8.2-py3-none-any.whl (990 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.1/990.1 kB 7.5 MB/s eta 0:00:00
# Collecting emoji (from stanza)
#   Downloading emoji-2.11.1-py2.py3-none-any.whl (433 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.8/433.8 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stanza) (1.25.2)
# Requirement already satisfied: protobuf>=3.15.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (3.20.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from stanza) (2.31.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from stanza) (3.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza) (0.10.2)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from stanza) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stanza) (4.66.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.3.0->stanza)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.3.0->stanza)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3.0->stanza) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.3.0->stanza)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->stanza) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3.0->stanza) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3.0->stanza) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, emoji, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stanza
# Successfully installed emoji-2.11.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 stanza-1.8.2
# Cloning into 'UD_Spanish-AnCora'...
# remote: Enumerating objects: 1347, done.
# remote: Counting objects: 100% (363/363), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 1347 (delta 282), reused 357 (delta 276), pack-reused 984
# Receiving objects: 100% (1347/1347), 432.33 MiB | 24.04 MiB/s, done.
# Resolving deltas: 100% (975/975), done.

# %% [markdown]
# ### Entrenamiento del modelo - cálculo de conteos
#
# Parta este modelo consideramos el cálculo de las probabilidades:
#
# $$P(t_i | w_i, t_{i-1}) =\frac{C(w_i, t_i, t_{i-1})}{C(w_i, t_{i-1})} $$
#
# * `uniqueFeatureDict` $C(tag|word,prevtag) = C(w_i, t_i, t_{i-1})$
# * `contextDict` $C(word,prevtag) = C(w_i, t_{i-1})$
#
# En este caso cuando consideremos el primer elemento de una frase $w_0$, no existirá un elemento anterior $w_{-1}$ y por lo tanto, tampoco una etiqueta previa $t_{-1}$, podemos modelar este problema asumiendo que existe una etiqueta "None", para estos casos:
#
# $$P(t_0|w_0,t_{-1}) = P(t_0|w_0,\text{"None"})$$

# %%
from conllu import parse_incr

uniqueFeatureDict = {}
contextDict = {}

tagtype = 'upos'
data_file = open("UD_Spanish-AnCora/es_ancora-ud-train.conllu", "r", encoding="utf-8")

# Calculando conteos (pre-probabilidades)
for tokenlist in parse_incr(data_file):
  prevtag = "None"
  for token in tokenlist:
    tag = token[tagtype]
    word = token['form'].lower()
    #C(tag|word,prevtag)
    largeKey = tag+'|'+word+','+prevtag
    if largeKey in uniqueFeatureDict.keys():
      uniqueFeatureDict[largeKey]+=1
    else:
      uniqueFeatureDict[largeKey]=1
    key = word+','+prevtag
    if key in contextDict.keys():
      contextDict[key]+=1
    else:
      contextDict[key]=1
    #print(largeKey, key, '\n')
    prevtag=tag

# %% [markdown]
# ### Entrenamiento del modelo - cálculo de probabilidades
#
# $$P(t_i|w_i, t_{i-1}) = \frac{C(t_i, w_i, t_{i-1})}{C(w_i, t_{i-1})}$$

# %%
posteriorProbDict = {}

for key in uniqueFeatureDict.keys():
  if len(key.split('|'))==3:
    posteriorProbDict[key] = uniqueFeatureDict[key]/contextDict['|'+key.split('|')[-1]]
  else:
    posteriorProbDict[key] = uniqueFeatureDict[key]/contextDict[key.split('|')[1]]

# %%
# Aquí verificamos que todas las probabilidades
# por cada contexto 'word,prevtag' suman 1.0

for base_context in contextDict.keys():
  countprob = 0
  items = 0
  for key in posteriorProbDict.keys():
    if len(key.split('|'))==3:
      if '|'+key.split('|')[-1]==base_context:
        countprob+=posteriorProbDict[key]
        items+=1
    else:
      if key.split('|')[1]==base_context:
        countprob+=posteriorProbDict[key]
        items+=1
  print(base_context, items, countprob)

# %% [markdown]
# ### Distribución inicial de estados latentes

# %%
# identificamos las categorias gramaticales 'upos' unicas en el corpus
stateSet = {'ADJ',
 'ADP',
 'ADV',
 'AUX',
 'CCONJ',
 'DET',
 'INTJ',
 'NOUN',
 'NUM',
 'PART',
 'PRON',
 'PROPN',
 'PUNCT',
 'SCONJ',
 'SYM',
 'VERB',
 '_'}
# enumeramos las categorias con numeros para asignar a
# las columnas de la matriz de Viterbi
tagStateDict = {}
for i, state in enumerate(stateSet):
  tagStateDict[state] = i
tagStateDict
# Out:
# {'ADJ': 9,
#  'ADP': 8,
#  'ADV': 1,
#  'AUX': 14,
#  'CCONJ': 4,
#  'DET': 12,
#  'INTJ': 15,
#  'NOUN': 2,
#  'NUM': 7,
#  'PART': 3,
#  'PRON': 5,
#  'PROPN': 0,
#  'PUNCT': 10,
#  'SCONJ': 6,
#  'SYM': 16,
#  'VERB': 11,
#  '_': 13}

# %%
initTagStateProb = {} # \rho_i^{(0)}
from conllu import parse_incr
wordList = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-train.conllu", "r", encoding="utf-8")
count = 0 # cuenta la longitud del corpus
for tokenlist in parse_incr(data_file):
  count += 1
  tag = tokenlist[0]['upos']
  if tag in initTagStateProb.keys():
    initTagStateProb[tag] += 1
  else:
    initTagStateProb[tag] = 1

for key in initTagStateProb.keys():
  initTagStateProb[key] /= count

initTagStateProb
# Out:
# {'ADJ': 0.010136315973435861,
#  'ADP': 0.1574274729115694,
#  'ADV': 0.07577770010485844,
#  'AUX': 0.022789234533379936,
#  'CCONJ': 0.036980076896190144,
#  'DET': 0.34799021321216356,
#  'INTJ': 0.0020272631946871723,
#  'NOUN': 0.025026214610276126,
#  'NUM': 0.0068507514854945824,
#  'PART': 0.002446696959105208,
#  'PRON': 0.04173365955959455,
#  'PROPN': 0.10506815798671792,
#  'PUNCT': 0.09143656064313177,
#  'SCONJ': 0.027123383432366307,
#  'SYM': 0.0004893393918210416,
#  'VERB': 0.04557846906675987,
#  '_': 0.0011184900384480952}

# %% [markdown]
# ### Construcción del algoritmo de Viterbi
#
# Dada una secuencia de palabras $\{p_1, p_2, \dots, p_n \}$, y un conjunto de categorias gramaticales dadas por la convención `upos`, se considera la matriz de probabilidades de Viterbi así:
#
# $$
# \begin{array}{c c}
# \begin{array}{c c c c}
# \text{ADJ} \\
# \text{ADV}\\
# \text{PRON} \\
# \vdots \\
# {}
# \end{array}
# &
# \left[
# \begin{array}{c c c c}
# \nu_1(\text{ADJ}) & \nu_2(\text{ADJ}) & \dots  & \nu_n(\text{ADJ})\\
# \nu_1(\text{ADV}) & \nu_2(\text{ADV}) & \dots  & \nu_n(\text{ADV})\\
# \nu_1(\text{PRON}) & \nu_2(\text{PRON}) & \dots  & \nu_n(\text{PRON})\\
# \vdots & \vdots & \dots & \vdots \\ \hdashline
# p_1 & p_2 & \dots & p_n
# \end{array}
# \right]
# \end{array}
# $$
#
# Donde las probabilidades de Viterbi en la primera columna (para una categoria $i$) están dadas por:
#
# $$
# \nu_1(i) = \underbrace{\rho_i^{(0)}}_{\text{probabilidad inicial}} \times P(i \vert p_1, \text{"None"})
# $$
#
# y para las siguientes columnas:
#
# $$
# \nu_{t}(j) = \max_i \{ \overbrace{\nu_{t-1}(i)}^{\text{estado anterior}} \times P(j \vert p_t, i) \}
# $$

# %%
import numpy as np
import stanza
stanza.download('es')
nlp = stanza.Pipeline('es', processors='tokenize')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.1.0.json: 122kB [00:00, 9.28MB/s]
# 2020-08-18 02:14:23 INFO: Downloading default packages for language: es (Spanish)...
# 2020-08-18 02:14:25 INFO: File exists: /root/stanza_resources/es/default.zip.
# 2020-08-18 02:14:31 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
def ViterbiMatrix(secuencia, posteriorProbDict=posteriorProbDict, initTagStateProb=initTagStateProb):
  doc = nlp(secuencia)
  if len(doc.sentences)>1:
    raise ValueError('secuencia must be a string!')
  seq = [word.text for word in doc.sentences[0].words]
  viterbiProb = np.zeros((17, len(seq)))

  # inicialización primera columna
  for tag in tagStateDict.keys():
    tag_row = tagStateDict[tag]
    key = tag+'|'+seq[0].lower()+','+"None"
    try:
      viterbiProb[tag_row, 0] = initTagStateProb[tag]*posteriorProbDict[key]
    except:
      pass

  # computo de las siguientes columnas
  for col in range(1, len(seq)):
    for tag in tagStateDict.keys():
      tag_row = tagStateDict[tag]
      possible_probs = []
      for prevtag in tagStateDict.keys():
        prevtag_row = tagStateDict[prevtag]
        key = tag+'|'+seq[col].lower()+','+prevtag
        try:
          possible_probs.append(
              viterbiProb[prevtag_row, col-1]*posteriorProbDict[key])
        except:
          possible_probs.append(0)
      viterbiProb[tag_row, col] = max(possible_probs)

  return viterbiProb

ViterbiMatrix('el mundo es pequeño')
# Out:
# array([[0.00000000e+00, 8.22024126e-03, 1.13643888e-04, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 3.39769972e-01, 5.94927966e-03, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.33820692e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [3.47990213e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 3.33820692e-01, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00]])

# %%
def ViterbiTags(secuencia, posteriorProbDict=posteriorProbDict, initTagStateProb=initTagStateProb):
  doc = nlp(secuencia)
  if len(doc.sentences)>1:
    raise ValueError('secuencia must be a string!')
  seq = [word.text for word in doc.sentences[0].words]
  viterbiProb = np.zeros((17, len(seq)))

  # inicialización primera columna
  for tag in tagStateDict.keys():
    tag_row = tagStateDict[tag]
    key = tag+'|'+seq[0].lower()+','+"None"
    try:
      viterbiProb[tag_row, 0] = initTagStateProb[tag]*posteriorProbDict[key]
    except:
      pass


  # computo de las siguientes columnas
  for col in range(1, len(seq)):
    for tag in tagStateDict.keys():
      tag_row = tagStateDict[tag]
      possible_probs = []
      for prevtag in tagStateDict.keys():
        prevtag_row = tagStateDict[prevtag]
        key = tag+'|'+seq[col].lower()+','+prevtag
        try:
          possible_probs.append(
              viterbiProb[prevtag_row, col-1]*posteriorProbDict[key])
        except:
          possible_probs.append(0)
      viterbiProb[tag_row, col] = max(possible_probs)

  # contruccion de secuencia de tags
  res = []
  for i, p in enumerate(seq):
    for tag in tagStateDict.keys():
      if tagStateDict[tag] == np.argmax(viterbiProb[:, i]):
        res.append((p, tag))


  return res

ViterbiTags('el mundo es pequeño')
# Out:
# [('el', 'DET'), ('mundo', 'NOUN'), ('es', 'AUX'), ('pequeño', 'ADJ')]

# %%
ViterbiTags('estos instrumentos han de rasgar')
# Out:
# [('estos', 'DET'),
#  ('instrumentos', 'NOUN'),
#  ('han', 'AUX'),
#  ('de', 'ADP'),
#  ('rasgar', 'PROPN')]

# %% [markdown]
# ## ¿ Siguientes Pasos ?
#
# El modelo construido, aunque es la base de un MEMM, no explota todo el potencial del concepto  que estos modelos representan, en nuestro caso sencillo consideramos solo un **feature** para predecir la categoría gramatical: $<w_i, t_{i-1}>$. Es decir, las probabilidades de una cierta etiqueta $t_i$ dada una observación $<w_i, t_{i-1}>$ se calculan contando eventos donde se observe que $<w_i, t_{i-1}>$ sucede simultáneamente con $t_i$.
#
# La generalización de esto (donde puedo considerar multiples observaciones o **features**, y a partir de estos inferir la categoría gramatical) se hace construyendo las llamadas **feature-functions**, donde estas funciones toman valores de 0 o 1, cuando se cumplan las condiciones de la observación o feature en cuestion. En general podemos considerar una **feature-function** como :
#
# $$f_a(t, o) = f_a(\text{tag}, \text{observation}) =
# \begin{cases}
#   1 , & \text{se cumple condición } a \\
#   0, & \text{en caso contrario}
# \end{cases}
# $$
#
# donde la condición $a$ es una relacion entre los valores que tome $\text{tag}$ y $\text{context}$, por ejemplo:
#
# $$f_a(t, o) = f_a(\text{tag}, \text{observation}) =
# \begin{cases}
#   1 , & (t_i, t_{i-1}) = \text{('VERB', 'ADJ')} \\
#   0, & \text{en caso contrario}
# \end{cases}
# $$
#
# Al considerar varias funciones, y por lo tanto varios features observables, consideramos una combinacion lineal de estos por medio de un coeficiente que multiplique a cada función:
#
# $$
# \theta_1 f_1(t, o) + \theta_2 f_2(t, o) + \dots
# $$
#
# donde los coeficientes indicarán cuales features son más relevantes y por lo tanto pesan más para la decisión del resultado del modelo. De esta manera los coeficientes $\theta_j$ se vuelven parámetros del modelo que deben ser optimizados (esto puede realizarse con cualquier técnica de optimizacion como el Gradiente Descendente). Ahora, las probabilidades que pueden obtener usando un softmax sobre estas combinaciones lineales de features:
#
# $$
# P = \prod_i \frac{\exp{\left(\sum_j \theta_j f_j(t_i, o)\right)}}{\sum_{t'}\exp{\left(\sum_j \theta_j f_j(t', o)\right)}}
# $$
#
# Así, lo que buscamos con el algoritmo de optimización es encontrar los parámetros $\theta_j$ que maximizan la probabilidad anterior. En NLTK encontramos la implementación completa de un clasificador de máxima entropia que no esta restringido a relaciones markovianas: https://www.nltk.org/_modules/nltk/classify/maxent.html
#
# Un segmento resumido de la clase en python que implementa este clasificador en NLTK lo encuentras así:
#
# ```
# class MaxentClassifier(ClassifierI):
#
#     def __init__(self, encoding, weights, logarithmic=True):
#         self._encoding = encoding
#         self._weights = weights
#         self._logarithmic = logarithmic
#         assert encoding.length() == len(weights)
#
#     def labels(self):
#         return self._encoding.labels()
#
#     def set_weights(self, new_weights):
#         self._weights = new_weights
#         assert self._encoding.length() == len(new_weights)
#
#
#     def weights(self):
#         return self._weights
#
#     def classify(self, featureset):
#         return self.prob_classify(featureset).max()
#
#     def prob_classify(self, featureset):
#         ### ...
#
#         # Normalize the dictionary to give a probability distribution
#         return DictionaryProbDist(prob_dict, log=self._logarithmic, normalize=True)
#
#     @classmethod
#     def train(
#         cls,
#         train_toks,
#         algorithm=None,
#         trace=3,
#         encoding=None,
#         labels=None,
#         gaussian_prior_sigma=0,
#         **cutoffs
#     ):
#      ### ......
# ```
#
# Donde te das cuenta de la forma que tienen las clases en NLTK que implementan clasificadores generales. Aquí vemos que la clase `MaxentClassifier` es una subclase de una más general `ClassifierI` la cual representa el proceso de clasificación general de categoría única (es decir, que a cada data-point le corresponda solo una categoria), también que esta clase depende de definir un `encoding`
#  y unos pesos `weights` :
#
# ```
# class MaxentClassifier(ClassifierI):
#
#     def __init__(self, encoding, weights, logarithmic=True):
# ```
#
# los pesos corresponden a los parámetros $\theta_i$. Y el encoding es el que corresponde a las funciones $f_a(t, o)$ que dan como resultado valores binarios $1$ o $0$.
#
# La documentación de NLTK te puede dar mas detalles de esta implementación: https://www.nltk.org/api/nltk.classify.html
#
# Finalmente, un ejemplo completo de uso y mejora de un modelo de máxima entropía, lo puedes encontrar en este fork que guarde especialmente para el curso, para que lo tengas de referencia y puedas jugar y aprender con él:
#
# https://github.com/pachocamacho1990/nltk-maxent-pos-tagger
#
# El cual fue desarrollado originalmente por Arne Neumann (https://github.com/arne-cl) basado en los fueatures propuestos por Ratnaparki en 1996 para la tarea de etiquetado por categorias gramaticales.

# %% [markdown]
# # Clasificación de palabras (por género de nombre)

# %%
import nltk, random
from nltk.corpus import names

# %%
nltk.download('names')
# Out:
# [nltk_data] Downloading package names to /root/nltk_data...
# [nltk_data]   Unzipping corpora/names.zip.
# True

# %% [markdown]
# **Función básica de extracción de atributos**

# %%
# definición de atributos relevantes
def atributos(palabra):
	return {'ultima_letra': palabra[-1]}

tagset = ([(name, 'male') for name in names.words('male.txt')] + [(name, 'female') for name in names.words('female.txt')])

# %%
tagset[:10]
# Out:
# [('Aamir', 'male'),
#  ('Aaron', 'male'),
#  ('Abbey', 'male'),
#  ('Abbie', 'male'),
#  ('Abbot', 'male'),
#  ('Abbott', 'male'),
#  ('Abby', 'male'),
#  ('Abdel', 'male'),
#  ('Abdul', 'male'),
#  ('Abdulkarim', 'male')]

# %%
random.shuffle(tagset)
tagset[:10]
# Out:
# [('Armond', 'male'),
#  ('Leodora', 'female'),
#  ('Webster', 'male'),
#  ('Ashlen', 'female'),
#  ('Talbert', 'male'),
#  ('Reeva', 'female'),
#  ('Linzy', 'female'),
#  ('Veronique', 'female'),
#  ('Fredrika', 'female'),
#  ('Earle', 'male')]

# %%
fset = [(atributos(n), g) for (n, g) in tagset]
train, test = fset[500:], fset[:500]

# %% [markdown]
# **Modelo de clasificación Naive Bayes**

# %%
# entrenamiento del modelo NaiveBayes
classifier = nltk.NaiveBayesClassifier.train(train)

# %% [markdown]
#  **Verificación de algunas predicciones**

# %%
classifier.classify(atributos('amanda'))
# Out:
# 'female'

# %%
classifier.classify(atributos('peter'))
# Out:
# 'male'

# %% [markdown]
# **Performance del modelo**

# %%
print(nltk.classify.accuracy(classifier, test))
# Out:
# 0.734

# %%
print(nltk.classify.accuracy(classifier, train))
# Out:
# 0.7647770016120365

# %% [markdown]
# **Mejores atributos**

# %%
def mas_atributos(nombre):
    atrib = {}
    atrib["primera_letra"] = nombre[0].lower()
    atrib["ultima_letra"] = nombre[-1].lower()
    for letra in 'abcdefghijklmnopqrstuvwxyz':
        atrib["count({})".format(letra)] = nombre.lower().count(letra)
        atrib["has({})".format(letra)] = (letra in nombre.lower())
    return atrib

# %%
mas_atributos('jhon')

# %%
fset = [(mas_atributos(n), g) for (n, g) in tagset]
train, test = fset[500:], fset[:500]
classifier2 = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(classifier2, test))
# Out:
# 0.77

# %% [markdown]
# ### Ejercicio de práctica
#
# **Objetivo:** Construye un classificador de nombres en español usando el siguiente dataset:
# https://github.com/jvalhondo/spanish-names-surnames

# %% [markdown]
# 1. **Preparación de los datos**: con un `git clone` puedes traer el dataset indicado a tu directorio en Colab, luego asegurate de darle el formato adecuado a los datos y sus features para que tenga la misma estructura del ejemplo anterior con el dataset `names` de nombres en ingles.
#
# * **Piensa y analiza**: ¿los features en ingles aplican de la misma manera para los nombres en español?

# %%
# escribe tu código aquí

# %% [markdown]
# 2. **Entrenamiento y performance del modelo**: usando el classificador de Naive Bayes de NLTK entrena un modelo sencillo usando el mismo feature de la última letra del nombre, prueba algunas predicciones y calcula el performance del modelo.

# %%
# escribe tu código aquí

# %% [markdown]
# 3. **Mejores atributos:** Define una función como `atributos2()` donde puedas extraer mejores atributos con los cuales entrenar una mejor version del clasificador. Haz un segundo entrenamiento y verifica como mejora el performance de tu modelo. ¿Se te ocurren mejores maneras de definir atributos para esta tarea particular?

# %%
# escribe tu código aquí

# %% [markdown]
# # Clasificación de documentos (email spam o no spam)

# %%
# !git clone https://github.com/pachocamacho1990/datasets
# Out:
# fatal: destination path 'datasets' already exists and is not an empty directory.

# %%
import pandas as pd
import numpy as np
from nltk import word_tokenize

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
df = pd.read_csv('datasets/email/csv/spam-apache.csv', names = ['clase','contenido'])
df['tokens'] = df['contenido'].apply(lambda x: word_tokenize(x))
df.head()
# Out:
#    clase  ...                                             tokens
# 0     -1  ...  [<, !, DOCTYPE, HTML, PUBLIC, ``, -//W3C//DTD,...
# 1      1  ...  [>, Russell, Turpin, :, >, >, That, depends, o...
# 2     -1  ...  [Help, wanted, ., We, are, a, 14, year, old, f...
# 3     -1  ...  [Request, A, Free, No, Obligation, Consultatio...
# 4      1  ...  [Is, there, a, way, to, look, for, a, particul...
#
# [5 rows x 3 columns]

# %%
df['tokens'].values[0]

# %%
all_words = nltk.FreqDist([w for tokenlist in df['tokens'].values for w in tokenlist])
top_words = all_words.most_common(200)

def document_features(document):
    document_words = set(document)
    features = {}
    for word in top_words:
        features['contains({})'.format(word)] = (word in document_words)
    return features

# %%
document_features(df['tokens'].values[0])

# %%
limit = 200
fset = [(document_features(texto), clase) for texto, clase in zip(df['tokens'].values, df['clase'].values)]
random.shuffle(fset)
train, test = fset[:limit], fset[limit:]

# %%
classifier = nltk.NaiveBayesClassifier.train(train)

# %%
print(nltk.classify.accuracy(classifier, test))
# Out:
# 0.48

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#     contains(('us', 53)) = False               1 : -1     =      1.0 : 1.0
#  contains(('could', 66)) = False               1 : -1     =      1.0 : 1.0
#  contains(('money', 72)) = False               1 : -1     =      1.0 : 1.0
#   contains(('days', 40)) = False               1 : -1     =      1.0 : 1.0
#   contains(('need', 43)) = False               1 : -1     =      1.0 : 1.0

# %%
df[df['clase']==-1]['contenido']
# Out:
# 0      <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# 2      Help wanted.  We are a 14 year old fortune 500...
# 3      Request A Free No Obligation Consultation!\nAc...
# 10     >\n>“µ×è¹µÑÇ ¡ÑºâÅ¡¸ØÃ¡Ô¨º¹ÍÔ¹àµÍÃìà¹çµ” \n>àµ...
# 11     ==============================================...
#                              ...
# 243    ##############################################...
# 244    Wanna see sexually curious teens playing with ...
# 246    REQUEST FOR URGENT BUSINESS ASSISTANCE\n------...
# 248    Email marketing works!  There's no way around ...
# 249    Email marketing works!  There's no way around ...
# Name: contenido, Length: 125, dtype: object

# %% [markdown]
# ## Ejercicio de práctica

# %% [markdown]
# ¿Como podrías construir un mejor clasificador de documentos?
#
# 0. **Dataset más grande:** El conjunto de datos que usamos fue muy pequeño, considera usar los archivos corpus que estan ubicados en la ruta: `datasets/email/plaintext/`
#
# 1. **Limpieza:** como te diste cuenta no hicimos ningun tipo de limpieza de texto en los correos electrónicos. Considera usar expresiones regulares, filtros por categorias gramaticales, etc ... .
#
# ---
#
# Con base en eso construye un dataset más grande y con un tokenizado más pulido.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# escribe tu código aquí:

# %% [markdown]
# 2. **Validación del modelo anterior:**
# ---
#
# una vez tengas el nuevo conjunto de datos más pulido y de mayor tamaño, considera el mismo entrenamiento con el mismo tipo de atributos del ejemplo anterior, ¿mejora el accuracy del modelo resultante?

# %%
# escribe tu código aquí:

# %% [markdown]
# 3. **Construye mejores atributos**: A veces no solo se trata de las palabras más frecuentes sino de el contexto, y capturar contexto no es posible solo viendo los tokens de forma individual, ¿que tal si consideramos bi-gramas, tri-gramas ...?, ¿las secuencias de palabras podrián funcionar como mejores atributos para el modelo?. Para ver si es así,  podemos extraer n-gramas de nuestro corpus y obtener sus frecuencias de aparición con `FreqDist()`, desarrolla tu propia manera de hacerlo y entrena un modelo con esos nuevos atributos, no olvides compartir tus resultados en la sección de comentarios.

# %%
# escribe tu código aquí:

# %%
import math
import os

# %%
os.listdir('corpus1/spam')

# %% [markdown]
# ## Preparación del corpus de emails

# %%
# !git clone https://github.com/pachocamacho1990/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39
# Unpacking objects: 100% (39/39), done.

# %%
! unzip datasets/email/plaintext/corpus1.zip

# %%
data = []
clases = []
#lectura de spam data
for file in os.listdir('corpus1/spam'):
  with open('corpus1/spam/'+file, encoding='latin-1') as f:
    data.append(f.read())
    clases.append('spam')
#lectura de ham data
for file in os.listdir('corpus1/ham'):
  with open('corpus1/ham/'+file, encoding='latin-1') as f:
    data.append(f.read())
    clases.append('ham')
len(data)
# Out:
# 5172

# %% [markdown]
# ## Construcción de modelo Naive Bayes

# %% [markdown]
# ### Tokenizador de Spacy
#
# * Documentación: https://spacy.io/api/tokenizer
# * ¿Cómo funciona el tokenizador? https://spacy.io/usage/linguistic-features#how-tokenizer-works

# %%
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English

nlp = English()
tokenizer = Tokenizer(nlp.vocab)

# %%
print([t.text for t in tokenizer(data[0])])
# Out:
# ['Subject:', 'brand', 'new', 'teenager', 'peeing', '\n', 'you', 'don', "'", 't', 'know', 'me', 'from', 'adam', '.', ':', ')', 'iyakubonana', '\n', 'nothing', 'that', 'you', 'have', 'not', 'given', 'away', 'will', 'ever', 'be', 'really', 'yours', '.', '\n', 'i', 'don', "'", 't', 'deserve', 'this', 'award', ',', 'but', 'i', 'have', 'arthritis', ',', 'and', 'i', 'don', "'", 't', 'deserve', 'that', ',', 'either', '.', 'the', 'most', 'important', 'thing', 'a', 'father', 'can', 'do', 'for', 'his', 'children', 'is', 'to', 'love', 'their', 'mother', '.', '\n', 'tricks', 'and', 'treachery', 'are', 'the', 'practice', 'of', 'fools', ',', 'that', 'don', "'", 't', 'have', 'brains', 'enough', 'to', 'be', 'honest', '.', '\n', 'a', 'heart', 'that', 'loves', 'is', 'always', 'young', '.', '\n', 'if', 'you', 'drink', ',', 'don', "'", 't', 'drive', '.', 'don', "'", 't', 'even', 'putt', '.', '\n', 'husbands', 'never', 'become', 'good', 'they', 'merely', 'become', 'proficient', '.', '\n', 'only', 'from', 'the', 'heart', 'can', 'you', 'touch', 'the', 'sky', '.', '\n', 'even', 'if', 'it', 'is', 'to', 'be', ',', 'what', 'end', 'do', 'you', 'serve', 'by', 'running', 'to', 'distress', '?', 'it', 'is', 'a', 'terrible', 'thing', 'to', 'look', 'over', 'your', 'shoulder', 'when', 'you', 'are', 'trying', 'to', 'lead', '-', '-', 'and', 'find', 'no', 'one', 'there', '.', '\n', 'i', 'hated', 'her', 'now', 'with', 'a', 'hatred', 'more', 'fatal', 'than', 'indifference', 'because', 'it', 'was', 'the', 'other', 'side', 'of', 'love', '.', '\n', 'reading', 'makes', 'a', 'full', 'man', ',', 'meditation', 'a', 'profound', 'man', ',', 'discourse', 'a', 'clear', 'man', '.', '\n', 'a', 'few', 'strong', 'instincts', 'and', 'a', 'few', 'plain', 'rules', 'suffice', 'us', '.', '\n', 'we', 'are', 'all', 'sentenced', 'to', 'solitary', 'confinement', 'inside', 'our', 'own', 'skins', ',', 'for', 'life', '.', '\n', 'eroticism', 'is', 'assenting', 'to', 'life', 'even', 'in', 'death', '.', '\n', 'truly', 'great', 'friends', 'are', 'hard', 'to', 'find', ',', 'difficult', 'to', 'leave', ',', 'and', 'impossible', 'to', 'forget', '.', '\n', 'the', 'weeping', 'of', 'an', 'heir', 'is', 'laughter', 'in', 'disguise', '.', 'the', 'harder', 'i', 'work', 'the', 'luckier', 'i', 'get', '.']

# %% [markdown]
# ### Clase principal para el algoritmo
#
# Recuerda que la clase más probable viene dada por (en espacio de cómputo logarítmico):
#
#
# $$\hat{c} = {\arg \max}_{(c)}\log{P(c)}
#  +\sum_{i=1}^n
# \log{ P(f_i \vert c)}
# $$
#
# Donde, para evitar casos atípicos, usaremos el suavizado de Laplace así:
#
# $$
# P(f_i \vert c) = \frac{C(f_i, c)+1}{C(c) + \vert V \vert}
# $$
#
# siendo $\vert V \vert$ la longitud del vocabulario de nuestro conjunto de entrenamiento.

# %%
import numpy as np

class NaiveBayesClassifier():
  nlp = English()
  tokenizer = Tokenizer(nlp.vocab)

  def tokenize(self, doc):
    return  [t.text.lower() for t in tokenizer(doc)]

  def word_counts(self, words):
    wordCount = {}
    for w in words:
      if w in wordCount.keys():
        wordCount[w] += 1
      else:
        wordCount[w] = 1
    return wordCount

  def fit(self, data, clases):
    n = len(data)
    self.unique_clases = set(clases)
    self.vocab = set()
    self.classCount = {} #C(c)
    self.log_classPriorProb = {} #P(c)
    self.wordConditionalCounts = {} #C(w|c)
    #conteos de clases
    for c in clases:
      if c in self.classCount.keys():
        self.classCount[c] += 1
      else:
        self.classCount[c] = 1
    # calculo de P(c)
    for c in self.classCount.keys():
      self.log_classPriorProb[c] = math.log(self.classCount[c]/n)
      self.wordConditionalCounts[c] = {}
    # calculo de C(w|c)
    for text, c in zip(data, clases):
      counts = self.word_counts(self.tokenize(text))
      for word, count in counts.items():
        if word not in self.vocab:
          self.vocab.add(word)
        if word not in self.wordConditionalCounts[c]:
          self.wordConditionalCounts[c][word] = 0.0
        self.wordConditionalCounts[c][word] += count

  def predict(self, data):
    results = []
    for text in data:
      words = set(self.tokenize(text))
      scoreProb = {}
      for word in words:
        if word not in self.vocab: continue #ignoramos palabras nuevas
        #suavizado Laplaciano para P(w|c)
        for c in self.unique_clases:
          log_wordClassProb = math.log(
              (self.wordConditionalCounts[c].get(word, 0.0)+1)/(self.classCount[c]+len(self.vocab)))
          scoreProb[c] = scoreProb.get(c, self.log_classPriorProb[c]) + log_wordClassProb
      arg_maxprob = np.argmax(np.array(list(scoreProb.values())))
      results.append(list(scoreProb.keys())[arg_maxprob])
    return results

# %% [markdown]
# ### Utilidades de Scikit Learn
# * `train_test_split`: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# * `accuracy_score`: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html
#
# * `precision_score`: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html
#
# * `recall_score`: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
data_train, data_test, clases_train, clases_test = train_test_split(data, clases, test_size=0.10, random_state=42)

# %%
classifier = NaiveBayesClassifier()
classifier.fit(data_train, clases_train)

# %%
clases_predict = classifier.predict(data_test)

# %%
accuracy_score(clases_test, clases_predict)
# Out:
# 0.8552123552123552

# %%
precision_score(clases_test, clases_predict, average=None, zero_division=1)
# Out:
# array([0.82876712, 1.        ])

# %%
recall_score(clases_test, clases_predict, average=None, zero_division=1)
# Out:
# array([1.        , 0.51612903])
