# %% [markdown]
# # Tabla de verdad

# %% [markdown]
# ![conclusion-5859031.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Un predicado lógico es una función cuyos parámetros son booleanos y su resultado también es booleano.
#
# Escriba la función `tabla_de_verdad(predicado)` que reciba como parámetro un predicado lógico de tres parámetros e imprima la tabla de verdad del predicado.:
#
# ```
# >>> def predicado(p, q, r):
# ...    return (not p) and (q or r)
# ...
# >>> tabla_verdad(predicado)
# p     q     r     predicado
# ===== ===== ===== =========
# True  True  True  False
# True  True  False False
# True  False True  False
# True  False False False
# False True  True  True
# False True  False True
# False False True  True
# False False False False
# ```
#
# Note que la función `tabla_de_verdad(predicado)` no retorna nada, sólo imprime la tabla.

# %% [markdown]
# ## Solucion

# %% [markdown]
# ### importacion de librerias

# %%
import pandas as pd

# %% [markdown]
# ### Funcion de la tabla de verdad

# %%
tabla = pd.DataFrame({'p' : [True, True, True, True, False, False, False, False], 
                      'q' : [True, True, False, False, True, True, False, False],
                      'r' : [True, False, True, False, True, False, True, False],
                      'predicado' : ''})

# %%
def tabla_verdad(p, q, r):
  for i in range(len(tabla)):
    tabla.iat[i, 3] = (not tabla.iloc[i]['p']) and (tabla.iloc[i]['q'] or tabla.iloc[i]['r'])
  
  print(tabla)

# %%
tabla_verdad(True, False, True)
# Out:
#        p      q      r predicado
# 0   True   True   True     False
# 1   True   True  False     False
# 2   True  False   True     False
# 3   True  False  False     False
# 4  False   True   True      True
# 5  False   True  False      True
# 6  False  False   True      True
# 7  False  False  False     False
