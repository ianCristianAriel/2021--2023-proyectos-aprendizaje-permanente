# %% [markdown]
# # Funcion de error personalizada con Tensorflow

# %%
# <-- analytics -->
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# <-- machine learning -->
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split
from keras import datasets

# <-- deep learning -->
import tensorflow as tf
from keras import models
from keras import layers

# %% [markdown]
# ## Huber loss

# %% [markdown]
# La función de pérdida de Huber describe la pena incurrida por un procedimiento de estimación f. Huber (1964) define la función de pérdida de forma fragmentada por:
#
# $$ {\displaystyle L_{\delta }(y,h(x))={\begin{cases}{\frac {1}{2}}(y-h(x))^{2} \hspace{1.5cm} {\textrm {for}}|y-h(x)|\leq \delta ,\\\delta \,|y-h(x)|-{\frac {1}{2}}\delta ^{2} \hspace{5mm} {\textrm {otherwise.}}\end{cases}}}$$
#
# Más información: https://en.wikipedia.org/wiki/Huber_loss

# %%
# Función que genera al función de pérdida de Huber
def create_huber(threshold=1.0):
    def huber_fn(y_true, y_pred):
        error = y_true - y_pred
        is_small_error = tf.abs(error) <= threshold
        squared_loss = tf.square(error) / 2
        linear_loss  = threshold * tf.abs(error) - threshold**2 / 2
        return tf.where(is_small_error, squared_loss, linear_loss)
    return huber_fn

# %% [markdown]
# A continuación se representa gráficamente la función de pérdida de Huber en función del threshold seleccionado

# %%
# El valor más habitual para la función de pérdida de Huber es 1.0
huber_fn = create_huber(1.0)

# %%
# Representación gráfica de la función de pérdida de Huber
plt.figure(figsize=(10, 5.5))

z = np.linspace(-4, 4, 200)

plt.plot(z, huber_fn(0, z), "b-", linewidth=2, label="huber($z$)")

plt.gca().axvline(x=0, color='k')
plt.axis([-4, 4, 0, 4])
plt.grid(True)
plt.xlabel("$z$")
plt.ylabel("$huber\_loss(0, z)$")
plt.legend(fontsize=14)
plt.title("Huber loss", fontsize=14)
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\_'
# <>:12: SyntaxWarning: invalid escape sequence '\_'
# /var/folders/sf/zv8w99hn1570688_wf9y1h280000gn/T/ipykernel_37743/2044618873.py:12: SyntaxWarning: invalid escape sequence '\_'
#   plt.ylabel("$huber\_loss(0, z)$")

# %% [markdown]
# ## Entrenando una Red Neuronal Artificial con la nueva función de error

# %% [markdown]
# A continuación se pone en práctica la función de error definida en el apartado anterior en un ejercicio práctico. Para ello, se va a utilizar el caso de uso práctico de predicción del precio de una vivienda presentado en la sección de introducción a Keras

# %% [markdown]
# ### Importando el conjunto de datos

# %%
boston_housing = datasets.boston_housing

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

# %%
features = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

df_train = pd.DataFrame(np.column_stack([X_train, y_train]), columns=features)
df_train.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0  1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1  0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2  4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3  0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4  3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# 5  0.28392   0.0   7.38   0.0  0.493  5.708   74.3  4.7211   5.0  287.0
# 6  9.18702   0.0  18.10   0.0  0.700  5.536  100.0  1.5804  24.0  666.0
# 7  4.09740   0.0  19.58   0.0  0.871  5.468  100.0  1.4118   5.0  403.0
# 8  2.15505   0.0  19.58   0.0  0.871  5.628  100.0  1.5166   5.0  403.0
# 9  1.62864   0.0  21.89   0.0  0.624  5.019  100.0  1.4394   4.0  437.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     21.0  396.90  18.72  15.2
# 1     14.7  395.38   3.11  42.3
# 2     20.2  375.52   3.26  50.0
# 3     20.2  396.90   8.01  21.1
# 4     20.2  391.43  14.65  17.7
# 5     19.6  391.13  11.74  18.5
# 6     20.2  396.90  23.60  11.3
# 7     14.7  396.90  26.42  15.6
# 8     14.7  169.27  16.65  15.6
# 9     21.2  396.90  34.41  14.4

# %% [markdown]
# ### División del conjunto de datos

# %%
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5)

# %% [markdown]
# ### Escalando el conjunto de datos

# %%
scaler = RobustScaler()

X_train_prep = scaler.fit_transform(X_train)
X_val_prep = scaler.transform(X_val)
X_test_prep = scaler.transform(X_test)

# %% [markdown]
# ### Definicion de la arquitectura de la Red Neuronal Artificial

# %%
network = models.Sequential()

network.add(layers.Dense(30, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(10, activation='relu'))
network.add(layers.Dense(1))
# Out:
# /Users/cristianariel/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
network.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 30)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           310 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 741 (2.89 KB)
#  Trainable params: 741 (2.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Entrenamiento de la Red Neuronal Artificial

# %% [markdown]
# #### Función de error utilizada en el ejercicio práctico de introducción a Keras

# %% [markdown]
# A continuación se muestra la representación gráfica de la evaluación de los valores resultantes de la función de error **_mean_squared_error_** durante el proceso de entrenamiento.

# %%
network.compile(
    loss='mean_squared_error',
    optimizer='adam',
    metrics=['mae']
               )

# %%
history = network.fit(X_train_prep, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 563.1220 - mae: 21.9892 - val_loss: 654.2863 - val_mae: 23.8106
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 593.2595 - mae: 22.3756 - val_loss: 635.2418 - val_mae: 23.3841
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 563.3715 - mae: 21.8435 - val_loss: 620.1785 - val_mae: 23.0361
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 549.2137 - mae: 21.5791 - val_loss: 605.2819 - val_mae: 22.6770
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 523.0816 - mae: 20.8702 - val_loss: 587.3477 - val_mae: 22.2392
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 506.1484 - mae: 20.3903 - val_loss: 565.3575 - val_mae: 21.7517
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 489.1475 - mae: 19.8298 - val_loss: 539.2938 - val_mae: 21.2427
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 484.5271 - mae: 19.8148 - val_loss: 507.4041 - val_mae: 20.6764
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 451.0886 - mae: 18.9798 - val_loss: 470.9392 - val_mae: 19.9474
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 420.1785 - mae: 18.3714 - val_loss: 430.3305 - val_mae: 19.0181
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 382.1008 - mae: 17.5641 - val_loss: 388.5673 - val_mae: 17.9265
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 355.8823 - mae: 16.7353 - val_loss: 344.8914 - val_mae: 16.6182
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 311.6288 - mae: 15.1970 - val_loss: 302.2471 - val_mae: 15.4227
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 292.7399 - mae: 14.6860 - val_loss: 266.3282 - val_mae: 14.5530
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 248.6584 - mae: 13.5773 - val_loss: 236.8722 - val_mae: 13.6996
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 225.8078 - mae: 12.9356 - val_loss: 213.0333 - val_mae: 12.9567
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 189.9427 - mae: 11.8475 - val_loss: 194.8330 - val_mae: 12.3063
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 179.3569 - mae: 11.3566 - val_loss: 178.2059 - val_mae: 11.6586
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 172.6318 - mae: 10.8174 - val_loss: 162.0901 - val_mae: 11.0432
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 150.4395 - mae: 10.2926 - val_loss: 147.0931 - val_mae: 10.4916
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135.4598 - mae: 9.6091 - val_loss: 132.2230 - val_mae: 9.9404
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 117.6299 - mae: 9.0644 - val_loss: 118.5361 - val_mae: 9.3513
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110.3813 - mae: 8.5723 - val_loss: 106.1609 - val_mae: 8.8244
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 101.7903 - mae: 8.2460 - val_loss: 93.9197 - val_mae: 8.2774
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 96.3300 - mae: 7.8530 - val_loss: 83.0757 - val_mae: 7.7325
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 87.0909 - mae: 7.4931 - val_loss: 72.8237 - val_mae: 7.1997
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 70.9263 - mae: 6.7610 - val_loss: 64.6219 - val_mae: 6.7301
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 64.8301 - mae: 6.5047 - val_loss: 56.8701 - val_mae: 6.2529
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.6864 - mae: 5.7501 - val_loss: 50.6439 - val_mae: 5.8620
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.3456 - mae: 5.3364 - val_loss: 45.0353 - val_mae: 5.4736
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.8953 - mae: 5.2506 - val_loss: 40.3144 - val_mae: 5.1363
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.9692 - mae: 4.6878 - val_loss: 36.4692 - val_mae: 4.8694
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.7328 - mae: 4.7623 - val_loss: 33.2469 - val_mae: 4.6478
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.7575 - mae: 4.6081 - val_loss: 30.8662 - val_mae: 4.4806
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.5322 - mae: 4.2908 - val_loss: 28.5774 - val_mae: 4.2863
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.0729 - mae: 4.0249 - val_loss: 26.9951 - val_mae: 4.1410
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.7727 - mae: 3.8337 - val_loss: 25.7036 - val_mae: 4.0213
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.2631 - mae: 3.8175 - val_loss: 24.4896 - val_mae: 3.9234
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.8111 - mae: 3.6609 - val_loss: 23.5514 - val_mae: 3.8234
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7360 - mae: 3.4581 - val_loss: 22.8248 - val_mae: 3.7626
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.1946 - mae: 3.5340 - val_loss: 22.3823 - val_mae: 3.7115
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0892 - mae: 3.5044 - val_loss: 21.8357 - val_mae: 3.6612
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.9672 - mae: 3.3885 - val_loss: 21.4178 - val_mae: 3.6306
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0388 - mae: 3.4824 - val_loss: 20.8636 - val_mae: 3.5757
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.2361 - mae: 3.0357 - val_loss: 20.8412 - val_mae: 3.5581
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.3157 - mae: 3.1308 - val_loss: 20.3798 - val_mae: 3.5070
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.8569 - mae: 3.2437 - val_loss: 20.1587 - val_mae: 3.4537
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.6426 - mae: 3.0976 - val_loss: 20.0827 - val_mae: 3.4486
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.9305 - mae: 2.8946 - val_loss: 19.5323 - val_mae: 3.3908
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.7115 - mae: 2.8721 - val_loss: 19.5646 - val_mae: 3.3904

# %%
pd.DataFrame(history.history)[['mae', 'val_mae']].plot(figsize=(10, 6))
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# #### Evaluación de los resultados

# %%
test_loss, test_mae = network.evaluate(X_test_prep, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.9859 - mae: 3.8660

# %%
print('test_mae:', test_mae)
# Out:
# test_mae: 3.8174211978912354

# %% [markdown]
# #### Función de error de Huber

# %% [markdown]
# A continuación se muestra la representación gráfica de la evaluación de los valores resultantes de la función de error de **_huber_** durante el proceso de entrenamiento.

# %%
network = models.Sequential()

network.add(layers.Dense(30, activation='relu', input_shape=X_train.shape[1:]))
network.add(layers.Dense(10, activation='relu'))
network.add(layers.Dense(1))
# Out:
# /Users/cristianariel/miniconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
network.compile(
    loss=create_huber(1.0),
    optimizer='adam',
    metrics=['mae']
               )

# %%
history = network.fit(X_train_prep, 
                      y_train, 
                      epochs=50, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 21.3105 - mae: 21.8105 - val_loss: 22.9684 - val_mae: 23.4684
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.5494 - mae: 22.0494 - val_loss: 22.5701 - val_mae: 23.0701
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.3190 - mae: 21.8187 - val_loss: 22.1187 - val_mae: 22.6187
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.5448 - mae: 21.0444 - val_loss: 21.6069 - val_mae: 22.1054
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7927 - mae: 20.2918 - val_loss: 21.0347 - val_mae: 21.5270
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7205 - mae: 19.2200 - val_loss: 20.5242 - val_mae: 21.0242
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.3275 - mae: 18.8250 - val_loss: 19.9430 - val_mae: 20.4342
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.6397 - mae: 18.1351 - val_loss: 19.2831 - val_mae: 19.7816
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.3351 - mae: 16.8310 - val_loss: 18.4833 - val_mae: 18.9740
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.7518 - mae: 17.2492 - val_loss: 17.4946 - val_mae: 17.9899
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.5676 - mae: 16.0661 - val_loss: 16.3459 - val_mae: 16.8458
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.5797 - mae: 15.0775 - val_loss: 15.0101 - val_mae: 15.5007
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.2036 - mae: 13.6968 - val_loss: 13.8509 - val_mae: 14.3500
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.2155 - mae: 12.7071 - val_loss: 12.9156 - val_mae: 13.4153
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4963 - mae: 11.9886 - val_loss: 12.0663 - val_mae: 12.5663
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.5221 - mae: 11.0164 - val_loss: 11.3264 - val_mae: 11.8249
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6147 - mae: 10.1074 - val_loss: 10.6329 - val_mae: 11.1272
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5433 - mae: 10.0366 - val_loss: 10.0113 - val_mae: 10.5099
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9715 - mae: 9.4655 - val_loss: 9.4002 - val_mae: 9.8923
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3111 - mae: 8.7980 - val_loss: 8.8842 - val_mae: 9.3783
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0582 - mae: 8.5431 - val_loss: 8.3941 - val_mae: 8.8778
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4863 - mae: 7.9718 - val_loss: 7.9038 - val_mae: 8.3887
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9186 - mae: 7.4014 - val_loss: 7.3915 - val_mae: 7.8849
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7919 - mae: 7.2834 - val_loss: 6.8903 - val_mae: 7.3758
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9581 - mae: 6.4459 - val_loss: 6.3657 - val_mae: 6.8559
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3480 - mae: 5.8331 - val_loss: 5.8439 - val_mae: 6.3150
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3099 - mae: 5.7906 - val_loss: 5.3522 - val_mae: 5.8145
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3864 - mae: 4.8669 - val_loss: 4.8871 - val_mae: 5.3574
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0157 - mae: 4.4924 - val_loss: 4.4959 - val_mae: 4.9530
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7521 - mae: 4.2217 - val_loss: 4.1073 - val_mae: 4.5853
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9599 - mae: 4.4308 - val_loss: 3.8195 - val_mae: 4.2944
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5791 - mae: 4.0546 - val_loss: 3.5578 - val_mae: 4.0189
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2216 - mae: 3.6965 - val_loss: 3.3570 - val_mae: 3.8156
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1224 - mae: 3.5872 - val_loss: 3.2282 - val_mae: 3.6983
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7143 - mae: 3.1782 - val_loss: 3.1569 - val_mae: 3.6078
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8800 - mae: 3.3460 - val_loss: 3.0654 - val_mae: 3.5154
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7420 - mae: 3.1957 - val_loss: 3.0253 - val_mae: 3.4706
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6380 - mae: 3.0922 - val_loss: 2.9890 - val_mae: 3.4360
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4319 - mae: 2.8922 - val_loss: 2.9634 - val_mae: 3.4066
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4592 - mae: 2.9066 - val_loss: 2.9308 - val_mae: 3.3743
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4944 - mae: 2.9536 - val_loss: 2.8970 - val_mae: 3.3437
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4463 - mae: 2.8911 - val_loss: 2.8786 - val_mae: 3.3366
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3253 - mae: 2.7758 - val_loss: 2.8393 - val_mae: 3.2977
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3823 - mae: 2.8459 - val_loss: 2.8026 - val_mae: 3.2627
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5681 - mae: 3.0229 - val_loss: 2.7792 - val_mae: 3.2454
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3379 - mae: 2.7870 - val_loss: 2.7307 - val_mae: 3.1924
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8875 - mae: 2.3404 - val_loss: 2.7368 - val_mae: 3.2121
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1387 - mae: 2.5912 - val_loss: 2.6827 - val_mae: 3.1498
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9045 - mae: 2.3575 - val_loss: 2.6828 - val_mae: 3.1501
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0946 - mae: 2.5515 - val_loss: 2.6254 - val_mae: 3.0942

# %%
pd.DataFrame(history.history)[['mae', 'val_mae']].plot(figsize=(10, 6))
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# #### Evaluación de los resultados

# %%
test_loss, test_mae = network.evaluate(X_test_prep, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5505 - mae: 3.0208

# %%
print('test_mae:', test_mae)
# Out:
# test_mae: 3.0607569217681885

# %% [markdown]
# ## Guardando el modelo en disco con objetos personalizados

# %% [markdown]
# Cuando nuestro modelo contiene algún componente personalizado, debemos realizar el siguiente procedimiento para almacenar el modelo en disco e importarlo cuando sea necesario

# %%
# Guardamos el modelo en disco
network.save("modelo_huber_loss.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Importamos el modelo previamente guardado en disco
network2 = keras.models.load_model("modelo_huber_loss.h5",
                                    custom_objects={"huber_fn": create_huber(1.0)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Importamos el modelo previamente guardado en disco
# ----> 2 network2 = keras.models.load_model("modelo_huber_loss.h5",
#       3                                       custom_objects={"huber_fn": create_huber(1.0)})
#
# NameError: name 'keras' is not defined

# %%
history = network2.fit(X_train_prep, 
                      y_train, 
                      epochs=2, 
                      validation_data=(X_val_prep, y_val))
# Out:
# Epoch 1/2
# 13/13 [==============================] - 0s 12ms/step - loss: 2.1799 - mean_absolute_error: 2.6326 - val_loss: 3.8635 - val_mean_absolute_error: 4.3035
# Epoch 2/2
# 13/13 [==============================] - 0s 3ms/step - loss: 2.1731 - mean_absolute_error: 2.6262 - val_loss: 3.8704 - val_mean_absolute_error: 4.3219
